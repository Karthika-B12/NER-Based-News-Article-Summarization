# %% [markdown]
# NER(to remove sentences without named entities) AND BERT(word embeddings)

# %%
import fitz  # PyMuPDF for PDF text extraction
import spacy
import torch
from transformers import BertModel, BertTokenizer
import numpy as np
from sklearn.cluster import KMeans
import nltk
from nltk.tokenize import sent_tokenize

# Download sentence tokenizer
nltk.download('punkt')
nltk.download('punkt_tab')

# Step 1: Extract Text from PDF
def extract_text_from_pdf(pdf_path):
    doc = fitz.open(pdf_path)
    text = ""
    for page in doc:
        text += page.get_text("text") + " "  # Extract text from each page
    return text.strip()

# Provide the path to your PDF file
pdf_path = "/content/nlp_ner_news_summ.pdf"
document_text = extract_text_from_pdf(pdf_path)

# Step 2: Split Text into Sentences
sentences = sent_tokenize(document_text)

# Load spaCy Named Entity Recognition Model
nlp = spacy.load("en_core_web_sm")

# Step 3: Perform Named Entity Recognition (NER) and Filter Sentences
def filter_sentences_with_entities(sentences):
    filtered_sentences = []
    for sentence in sentences:
        doc = nlp(sentence)
        if len(doc.ents) > 0:  # Keep only sentences containing named entities
            filtered_sentences.append(sentence)
    return filtered_sentences

filtered_sentences = filter_sentences_with_entities(sentences)
print(f"Sentences after NER filtering: {filtered_sentences}")

# Load BERT Model
tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")
model = BertModel.from_pretrained("bert-base-uncased")

# Step 4: Convert Sentences to BERT Embeddings
def get_sentence_embedding(sentence):
    inputs = tokenizer(sentence, return_tensors="pt", padding=True, truncation=True, max_length=512)
    with torch.no_grad():
        outputs = model(**inputs)
    # Take the mean of the last hidden state to get sentence embedding
    return outputs.last_hidden_state.mean(dim=1).squeeze().numpy()

sentence_embeddings = np.array([get_sentence_embedding(sent) for sent in filtered_sentences])

# Step 5: Cluster the Sentences
num_clusters = 5  # Assuming we want 5 clusters
kmeans = KMeans(n_clusters=num_clusters, random_state=42, n_init=10)
kmeans.fit(sentence_embeddings)
clusters = kmeans.labels_

# Step 6: Generate Summary (Select One Representative Sentence from Each Cluster)
summary = []
for cluster_id in range(num_clusters):
    cluster_sentences = [filtered_sentences[i] for i in range(len(filtered_sentences)) if clusters[i] == cluster_id]
    if cluster_sentences:
        summary.append(cluster_sentences[0])  # Picking the first sentence in each cluster

# Print the final summary
print("\nGenerated Summary:")
for sentence in summary:
    print("-", sentence)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# Sentences after NER filtering: ['The recent parliamentary elections in Washington, D.C. resulted in a coalition government, \nshifting the balance of power.', 'The new administration, led by the Democratic Party, proposed \na tax reform bill, sparking intense debates across the country.', 'Opposition leaders from the \nRepublican Party called for revisions, claiming the bill favors large corporations like Amazon \nand Google over citizens.', 'Protests erupted in major cities such as New York and Los Angeles \nas activists demanded a more transparent legislative process.', 'The national football team of Brazil won a dramatic final match in Rio de Janeiro, clinching \ntheir first championship title in years.', "Analysts from ESPN praised the coach's strategic \nsubstitutions, crediting them for the late-game turnaround.", 'Meanwhile, FIFA announced an \nexpansion plan, adding two new teams next season.', 'A highly anticipated Hollywood blockbuster produced by Warner Bros. broke box office \nrecords, earning the highest opening weekend revenue.', 'The film’s success boosted the \nstudio’s stock prices on the New York Stock Exchange, reflecting strong investor confidence.', 'Fans praised lead actor Leonardo DiCaprio’s performance, fueling awards season speculation.', 'Meanwhile, director Christopher Nolan announced a sequel, promising an even more thrilling \nstoryline.', 'Streaming platforms like Netflix and Disney+ rushed to acquire exclusive rights, \nintensifying competition in the industry.', 'Apple unveiled an AI-powered device at its headquarters in Cupertino, California, \nrevolutionizing personal computing.', 'The innovation spurred interest from global investors, \ncausing Apple’s stock to surge on the Nasdaq.', 'However, privacy concerns emerged as critics \nquestioned data security measures implemented by Meta and Google.', 'Regulators from the \nEuropean Union launched an inquiry into potential ethical implications of AI integration.', 'In \nresponse, Apple pledged to implement stricter policies to address public concerns.', 'Tech giants like Microsoft and Tesla reported record earnings, causing a sharp rise in the stock \nmarket.', 'However, market analysts from Bloomberg warned of potential volatility due to \nrising interest rates set by the Federal Reserve.', 'The energy sector saw mixed results, with oil \nprices fluctuating amid geopolitical tensions in the Middle East.', 'Despite uncertainties, \nrenewable energy stocks, including Tesla and NextEra Energy, continued to experience steady \ngrowth.']
#
# Generated Summary:
# - The national football team of Brazil won a dramatic final match in Rio de Janeiro, clinching
# their first championship title in years.
# - The recent parliamentary elections in Washington, D.C. resulted in a coalition government,
# shifting the balance of power.
# - A highly anticipated Hollywood blockbuster produced by Warner Bros. broke box office
# records, earning the highest opening weekend revenue.
# - Opposition leaders from the
# Republican Party called for revisions, claiming the bill favors large corporations like Amazon
# and Google over citizens.
# - Streaming platforms like Netflix and Disney+ rushed to acquire exclusive rights,
# intensifying competition in the industry.

# %%
# !pip install pymupdf
# Out:
# Requirement already satisfied: pymupdf in /usr/local/lib/python3.11/dist-packages (1.25.4)

# %% [markdown]
# # **CLUSTERING (BERT SPACY AND K MEANS)**

# %%
import fitz  # PyMuPDF for PDF text extraction
import spacy
import torch
from transformers import BertModel, BertTokenizer
import numpy as np
from sklearn.cluster import KMeans
import nltk
from nltk.tokenize import sent_tokenize

# Download sentence tokenizer
nltk.download('punkt')
nltk.download('punkt_tab')

# Step 1: Extract Text from PDF
def extract_text_from_pdf(pdf_path):
    doc = fitz.open(pdf_path)
    text = ""
    for page in doc:
        text += page.get_text("text") + " "  # Extract text from each page
    return text.strip()

# Provide the path to your PDF file
pdf_path = "/content/nlp_ner_news_summ.pdf"
document_text = extract_text_from_pdf(pdf_path)

# Step 2: Split Text into Sentences
sentences = sent_tokenize(document_text)

# Load spaCy Named Entity Recognition Model
nlp = spacy.load("en_core_web_sm")

# Step 3: Perform Named Entity Recognition (NER) and Filter Sentences
def filter_sentences_with_entities(sentences):
    filtered_sentences = []
    for sentence in sentences:
        doc = nlp(sentence)
        if len(doc.ents) > 0:  # Keep only sentences containing named entities
            filtered_sentences.append(sentence)
    return filtered_sentences

filtered_sentences = filter_sentences_with_entities(sentences)
print(f"\n🔹 Sentences after NER filtering ({len(filtered_sentences)} sentences):\n")
for sent in filtered_sentences:
    print("-", sent)

# Load BERT Model
tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")
model = BertModel.from_pretrained("bert-base-uncased")

# Step 4: Convert Sentences to BERT Embeddings
def get_sentence_embedding(sentence):
    inputs = tokenizer(sentence, return_tensors="pt", padding=True, truncation=True, max_length=512)
    with torch.no_grad():
        outputs = model(**inputs)
    # Take the mean of the last hidden state to get sentence embedding
    return outputs.last_hidden_state.mean(dim=1).squeeze().numpy()

sentence_embeddings = np.array([get_sentence_embedding(sent) for sent in filtered_sentences])

# Step 5: Cluster the Sentences
num_clusters = 5  # Assuming we want 5 clusters
kmeans = KMeans(n_clusters=num_clusters, random_state=42, n_init=10)
kmeans.fit(sentence_embeddings)
clusters = kmeans.labels_

# Step 6: Print Clusters and their Sentences
print("\n🔹 Clusters and their Sentences:\n")
cluster_dict = {i: [] for i in range(num_clusters)}
for i, sentence in enumerate(filtered_sentences):
    cluster_dict[clusters[i]].append(sentence)

for cluster_id, cluster_sentences in cluster_dict.items():
    print(f"\n📌 Cluster {cluster_id + 1}:")
    for sent in cluster_sentences:
        print("-", sent)

# Step 7: Generate Summary (Select One Representative Sentence from Each Cluster)
summary = []
for cluster_id in range(num_clusters):
    if cluster_dict[cluster_id]:
        summary.append(cluster_dict[cluster_id][0])  # Picking the first sentence in each cluster
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# 🔹 Sentences after NER filtering (21 sentences):
#
# - The recent parliamentary elections in Washington, D.C. resulted in a coalition government,
# shifting the balance of power.
# - The new administration, led by the Democratic Party, proposed
# a tax reform bill, sparking intense debates across the country.
# - Opposition leaders from the
# Republican Party called for revisions, claiming the bill favors large corporations like Amazon
# and Google over citizens.
# - Protests erupted in major cities such as New York and Los Angeles
# as activists demanded a more transparent legislative process.
# - The national football team of Brazil won a dramatic final match in Rio de Janeiro, clinching
# their first championship title in years.
# - Analysts from ESPN praised the coach's strategic
# substitutions, crediting them for the late-game turnaround.
# - Meanwhile, FIFA announced an
# expansion plan, adding two new teams next season.
# - A highly anticipated Hollywood blockbuster produced by Warner Bros. broke box office
# records, earning the highest opening weekend revenue.
# - The film’s success boosted the
# studio’s stock prices on the New York Stock Exchange, reflecting strong investor confidence.
# - Fans praised lead actor Leonardo DiCaprio’s performance, fueling awards season speculation.
# - Meanwhile, director Christopher Nolan announced a sequel, promising an even more thrilling
# storyline.
# - Streaming platforms like Netflix and Disney+ rushed to acquire exclusive rights,
# intensifying competition in the industry.
# - Apple unveiled an AI-powered device at its headquarters in Cupertino, California,
# revolutionizing personal computing.
# - The innovation spurred interest from global investors,
# causing Apple’s stock to surge on the Nasdaq.
# - However, privacy concerns emerged as critics
# questioned data security measures implemented by Meta and Google.
# - Regulators from the
# European Union launched an inquiry into potential ethical implications of AI integration.
# - In
# response, Apple pledged to implement stricter policies to address public concerns.
# - Tech giants like Microsoft and Tesla reported record earnings, causing a sharp rise in the stock
# market.
# - However, market analysts from Bloomberg warned of potential volatility due to
# rising interest rates set by the Federal Reserve.
# - The energy sector saw mixed results, with oil
# prices fluctuating amid geopolitical tensions in the Middle East.
# - Despite uncertainties,
# renewable energy stocks, including Tesla and NextEra Energy, continued to experience steady
# growth.
#
# 🔹 Clusters and their Sentences:
#
#
# 📌 Cluster 1:
# - The national football team of Brazil won a dramatic final match in Rio de Janeiro, clinching
# their first championship title in years.
# - Meanwhile, FIFA announced an
# expansion plan, adding two new teams next season.
#
# 📌 Cluster 2:
# - The recent parliamentary elections in Washington, D.C. resulted in a coalition government,
# shifting the balance of power.
# - The new administration, led by the Democratic Party, proposed
# a tax reform bill, sparking intense debates across the country.
# - Protests erupted in major cities such as New York and Los Angeles
# as activists demanded a more transparent legislative process.
#
# 📌 Cluster 3:
# - A highly anticipated Hollywood blockbuster produced by Warner Bros. broke box office
# records, earning the highest opening weekend revenue.
# - The film’s success boosted the
# studio’s stock prices on the New York Stock Exchange, reflecting strong investor confidence.
# - Fans praised lead actor Leonardo DiCaprio’s performance, fueling awards season speculation.
# - Meanwhile, director Christopher Nolan announced a sequel, promising an even more thrilling
# storyline.
#
# 📌 Cluster 4:
# - Opposition leaders from the
# Republican Party called for revisions, claiming the bill favors large corporations like Amazon
# and Google over citizens.
# - Analysts from ESPN praised the coach's strategic
# substitutions, crediting them for the late-game turnaround.
# - However, privacy concerns emerged as critics
# questioned data security measures implemented by Meta and Google.
# - Regulators from the
# European Union launched an inquiry into potential ethical implications of AI integration.
# - In
# response, Apple pledged to implement stricter policies to address public concerns.
#
# 📌 Cluster 5:
# - Streaming platforms like Netflix and Disney+ rushed to acquire exclusive rights,
# intensifying competition in the industry.
# - Apple unveiled an AI-powered device at its headquarters in Cupertino, California,
# revolutionizing personal computing.
# - The innovation spurred interest from global investors,
# causing Apple’s stock to surge on the Nasdaq.
# - Tech giants like Microsoft and Tesla reported record earnings, causing a sharp rise in the stock
# market.
# - However, market analysts from Bloomberg warned of potential volatility due to
# rising interest rates set by the Federal Reserve.
# - The energy sector saw mixed results, with oil
# prices fluctuating amid geopolitical tensions in the Middle East.
# - Despite uncertainties,
# renewable energy stocks, including Tesla and NextEra Energy, continued to experience steady
# growth.

# %%
import fitz  # PyMuPDF for PDF text extraction
import spacy
import torch
from transformers import BertModel, BertTokenizer
import numpy as np
from sklearn.cluster import KMeans
from sklearn.metrics.pairwise import cosine_similarity
import nltk
from nltk.tokenize import sent_tokenize

# Download sentence tokenizer
nltk.download('punkt')

# Step 1: Extract Text from PDF
def extract_text_from_pdf(pdf_path):
    doc = fitz.open(pdf_path)
    text = ""
    for page in doc:
        text += page.get_text("text") + " "  # Extract text from each page
    return text.strip()

# Provide the path to your PDF file
pdf_path = "/content/nlp_ner_news_summ.pdf"
document_text = extract_text_from_pdf(pdf_path)

# Step 2: Split Text into Sentences
sentences = sent_tokenize(document_text)

# Load spaCy Named Entity Recognition Model
nlp = spacy.load("en_core_web_sm")

# Step 3: Perform Named Entity Recognition (NER) and Filter Sentences
def filter_sentences_with_entities(sentences):
    filtered_sentences = []
    for sentence in sentences:
        doc = nlp(sentence)
        if len(doc.ents) > 0:  # Keep only sentences containing named entities
            filtered_sentences.append(sentence)
    return filtered_sentences

filtered_sentences = filter_sentences_with_entities(sentences)

print("\n🔹 Sentences after NER Preprocessing:")
for sent in filtered_sentences:
    print("-", sent)

# Load BERT Model
tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")
model = BertModel.from_pretrained("bert-base-uncased")

# Step 4: Convert Sentences to BERT Embeddings
def get_sentence_embedding(sentence):
    inputs = tokenizer(sentence, return_tensors="pt", padding=True, truncation=True, max_length=512)
    with torch.no_grad():
        outputs = model(**inputs)
    return outputs.last_hidden_state.mean(dim=1).squeeze().numpy()

sentence_embeddings = np.array([get_sentence_embedding(sent) for sent in filtered_sentences])

# Step 5: Cluster the Sentences
num_clusters = 5  # Assuming 5 clusters
kmeans = KMeans(n_clusters=num_clusters, random_state=42, n_init=10)
kmeans.fit(sentence_embeddings)
clusters = kmeans.labels_

# Step 6: Identify Centroid Sentence in Each Cluster
def find_centroid_sentence(cluster_sentences, cluster_embeddings):
    similarity_matrix = cosine_similarity(cluster_embeddings)
    centroid_idx = np.argmax(np.mean(similarity_matrix, axis=1))
    return cluster_sentences[centroid_idx], centroid_idx, similarity_matrix

# Step 7: Identify Misclassified Sentences
cluster_dict = {i: [] for i in range(num_clusters)}
cluster_embeddings_dict = {i: [] for i in range(num_clusters)}
for i, sentence in enumerate(filtered_sentences):
    cluster_dict[clusters[i]].append(sentence)
    cluster_embeddings_dict[clusters[i]].append(sentence_embeddings[i])

misclassified_sentences = []
centroid_sentences = {}
intra_cluster_similarities = {}

for cluster_id in range(num_clusters):
    if len(cluster_dict[cluster_id]) > 0:
        centroid_sentence, centroid_idx, similarity_matrix = find_centroid_sentence(cluster_dict[cluster_id], np.array(cluster_embeddings_dict[cluster_id]))
        centroid_sentences[cluster_id] = centroid_sentence
        centroid_embedding = cluster_embeddings_dict[cluster_id][centroid_idx]
        intra_cluster_similarities[cluster_id] = similarity_matrix

        # Compute similarity with centroid and identify misclassified sentences
        for i, sentence in enumerate(cluster_dict[cluster_id]):
            similarity = cosine_similarity([centroid_embedding], [cluster_embeddings_dict[cluster_id][i]])[0][0]
            if similarity < np.mean(cosine_similarity([centroid_embedding], cluster_embeddings_dict[cluster_id])):
                misclassified_sentences.append((sentence, cluster_id, similarity))

# Step 8: Print Results
print("\n🔹 Clusters and their Centroids:")
for cluster_id, sentence in centroid_sentences.items():
    print(f"📌 Cluster {cluster_id + 1} Centroid Sentence:")
    print(f"   - {sentence}\n")
    print("   Sentences in Cluster:")
    for sent in cluster_dict[cluster_id]:
        print(f"   - {sent}")
    print()


# Step 9: Print Intra-Cluster Similarity Scores
print("\n🔹 Intra-Cluster Similarity Scores:")
for cluster_id, similarity_matrix in intra_cluster_similarities.items():
    print(f"📌 Cluster {cluster_id + 1} Similarity Scores:")
    print(similarity_matrix)

# Step 10: Compute and Print Pairwise Similarity Scores
print("\n🔹 Pairwise Similarity Scores Between Sentences:")
pairwise_similarity = cosine_similarity(sentence_embeddings)
print(pairwise_similarity)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 🔹 Sentences after NER Preprocessing:
# - The recent parliamentary elections in Washington, D.C. resulted in a coalition government,
# shifting the balance of power.
# - The new administration, led by the Democratic Party, proposed
# a tax reform bill, sparking intense debates across the country.
# - Opposition leaders from the
# Republican Party called for revisions, claiming the bill favors large corporations like Amazon
# and Google over citizens.
# - Protests erupted in major cities such as New York and Los Angeles
# as activists demanded a more transparent legislative process.
# - The national football team of Brazil won a dramatic final match in Rio de Janeiro, clinching
# their first championship title in years.
# - Analysts from ESPN praised the coach's strategic
# substitutions, crediting them for the late-game turnaround.
# - Meanwhile, FIFA announced an
# expansion plan, adding two new teams next season.
# - A highly anticipated Hollywood blockbuster produced by Warner Bros. broke box office
# records, earning the highest opening weekend revenue.
# - The film’s success boosted the
# studio’s stock prices on the New York Stock Exchange, reflecting strong investor confidence.
# - Fans praised lead actor Leonardo DiCaprio’s performance, fueling awards season speculation.
# - Meanwhile, director Christopher Nolan announced a sequel, promising an even more thrilling
# storyline.
# - Streaming platforms like Netflix and Disney+ rushed to acquire exclusive rights,
# intensifying competition in the industry.
# - Apple unveiled an AI-powered device at its headquarters in Cupertino, California,
# revolutionizing personal computing.
# - The innovation spurred interest from global investors,
# causing Apple’s stock to surge on the Nasdaq.
# - However, privacy concerns emerged as critics
# questioned data security measures implemented by Meta and Google.
# - Regulators from the
# European Union launched an inquiry into potential ethical implications of AI integration.
# - In
# response, Apple pledged to implement stricter policies to address public concerns.
# - Tech giants like Microsoft and Tesla reported record earnings, causing a sharp rise in the stock
# market.
# - However, market analysts from Bloomberg warned of potential volatility due to
# rising interest rates set by the Federal Reserve.
# - The energy sector saw mixed results, with oil
# prices fluctuating amid geopolitical tensions in the Middle East.
# - Despite uncertainties,
# renewable energy stocks, including Tesla and NextEra Energy, continued to experience steady
# growth.
#
# 🔹 Clusters and their Centroids:
# 📌 Cluster 1 Centroid Sentence:
#    - The national football team of Brazil won a dramatic final match in Rio de Janeiro, clinching
# their first championship title in years.
#
#    Sentences in Cluster:
#    - The national football team of Brazil won a dramatic final match in Rio de Janeiro, clinching
# their first championship title in years.
#    - Meanwhile, FIFA announced an
# expansion plan, adding two new teams next season.
#
# 📌 Cluster 2 Centroid Sentence:
#    - The new administration, led by the Democratic Party, proposed
# a tax reform bill, sparking intense debates across the country.
#
#    Sentences in Cluster:
#    - The recent parliamentary elections in Washington, D.C. resulted in a coalition government,
# shifting the balance of power.
#    - The new administration, led by the Democratic Party, proposed
# a tax reform bill, sparking intense debates across the country.
#    - Protests erupted in major cities such as New York and Los Angeles
# as activists demanded a more transparent legislative process.
#
# 📌 Cluster 3 Centroid Sentence:
#    - A highly anticipated Hollywood blockbuster produced by Warner Bros. broke box office
# records, earning the highest opening weekend revenue.
#
#    Sentences in Cluster:
#    - A highly anticipated Hollywood blockbuster produced by Warner Bros. broke box office
# records, earning the highest opening weekend revenue.
#    - The film’s success boosted the
# studio’s stock prices on the New York Stock Exchange, reflecting strong investor confidence.
#    - Fans praised lead actor Leonardo DiCaprio’s performance, fueling awards season speculation.
#    - Meanwhile, director Christopher Nolan announced a sequel, promising an even more thrilling
# storyline.
#
# 📌 Cluster 4 Centroid Sentence:
#    - However, privacy concerns emerged as critics
# questioned data security measures implemented by Meta and Google.
#
#    Sentences in Cluster:
#    - Opposition leaders from the
# Republican Party called for revisions, claiming the bill favors large corporations like Amazon
# and Google over citizens.
#    - Analysts from ESPN praised the coach's strategic
# substitutions, crediting them for the late-game turnaround.
#    - However, privacy concerns emerged as critics
# questioned data security measures implemented by Meta and Google.
#    - Regulators from the
# European Union launched an inquiry into potential ethical implications of AI integration.
#    - In
# response, Apple pledged to implement stricter policies to address public concerns.
#
# 📌 Cluster 5 Centroid Sentence:
#    - Tech giants like Microsoft and Tesla reported record earnings, causing a sharp rise in the stock
# market.
#
#    Sentences in Cluster:
#    - Streaming platforms like Netflix and Disney+ rushed to acquire exclusive rights,
# intensifying competition in the industry.
#    - Apple unveiled an AI-powered device at its headquarters in Cupertino, California,
# revolutionizing personal computing.
#    - The innovation spurred interest from global investors,
# causing Apple’s stock to surge on the Nasdaq.
#    - Tech giants like Microsoft and Tesla reported record earnings, causing a sharp rise in the stock
# market.
#    - However, market analysts from Bloomberg warned of potential volatility due to
# rising interest rates set by the Federal Reserve.
#    - The energy sector saw mixed results, with oil
# prices fluctuating amid geopolitical tensions in the Middle East.
#    - Despite uncertainties,
# renewable energy stocks, including Tesla and NextEra Energy, continued to experience steady
# growth.
#
#
# 🔹 Intra-Cluster Similarity Scores:
# 📌 Cluster 1 Similarity Scores:
# [[0.99999994 0.72614455]
#  [0.72614455 0.9999999 ]]
# 📌 Cluster 2 Similarity Scores:
# [[0.99999964 0.802541   0.7482577 ]
#  [0.802541   0.9999998  0.7724773 ]
#  [0.7482577  0.7724773  1.        ]]
# 📌 Cluster 3 Similarity Scores:
# [[1.         0.78048193 0.722726   0.7099848 ]
#  [0.78048193 1.         0.6843884  0.67760146]
#  [0.722726   0.6843884  0.99999976 0.77712965]
#  [0.7099848  0.67760146 0.77712965 1.        ]]
# 📌 Cluster 4 Similarity Scores:
# [[1.0000002  0.6993152  0.8012282  0.7339184  0.7844825 ]
#  [0.6993152  1.0000001  0.6605631  0.6379624  0.6470976 ]
#  [0.8012282  0.6605631  0.9999998  0.7876343  0.8188716 ]
#  [0.7339184  0.6379624  0.7876343  1.0000001  0.7613255 ]
#  [0.7844825  0.6470976  0.8188716  0.7613255  0.99999946]]
# 📌 Cluster 5 Similarity Scores:
# [[1.0000001  0.67805016 0.78465074 0.82266086 0.71390843 0.7757392
#   0.78047836]
#  [0.67805016 1.         0.7326703  0.7273079  0.5734066  0.61004037
# %%
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# Compute intra-cluster similarity scores
print("\n🔹 Intra-Cluster Similarity Scores:")
for cluster_id in range(num_clusters):
    if len(cluster_dict[cluster_id]) > 1:
        cluster_embeddings = np.array(cluster_embeddings_dict[cluster_id])
        similarity_matrix = cosine_similarity(cluster_embeddings)
        print(f"\n📌 Cluster {cluster_id + 1}:")
        for i in range(len(cluster_dict[cluster_id])):
            for j in range(i + 1, len(cluster_dict[cluster_id])):
                print(f"   • \"{cluster_dict[cluster_id][i]}\"")
                print(f"     🔹 ↔ Similarity with → \"{cluster_dict[cluster_id][j]}\"")
                print(f"       ✅ Score: {similarity_matrix[i][j]:.4f}\n")

# Compute similarity between all filtered sentences
print("\n🔹 Pairwise Sentence Similarity Scores:")
sentence_sim_matrix = cosine_similarity(sentence_embeddings)
for i in range(len(filtered_sentences)):
    for j in range(i + 1, len(filtered_sentences)):
        print(f"   🔵 Sentence 1: \"{filtered_sentences[i]}\"")
        print(f"   🔵 Sentence 2: \"{filtered_sentences[j]}\"")
        print(f"     🔹 ✅ Similarity Score: {sentence_sim_matrix[i][j]:.4f}\n")
# Out:
# 🔹 Intra-Cluster Similarity Scores:
#
# 📌 Cluster 1:
#    • "The national football team of Brazil won a dramatic final match in Rio de Janeiro, clinching
# their first championship title in years."
#      🔹 ↔ Similarity with → "Meanwhile, FIFA announced an
# expansion plan, adding two new teams next season."
#        ✅ Score: 0.7261
#
#
# 📌 Cluster 2:
#    • "The recent parliamentary elections in Washington, D.C. resulted in a coalition government,
# shifting the balance of power."
#      🔹 ↔ Similarity with → "The new administration, led by the Democratic Party, proposed
# a tax reform bill, sparking intense debates across the country."
#        ✅ Score: 0.8025
#
#    • "The recent parliamentary elections in Washington, D.C. resulted in a coalition government,
# shifting the balance of power."
#      🔹 ↔ Similarity with → "Protests erupted in major cities such as New York and Los Angeles
# as activists demanded a more transparent legislative process."
#        ✅ Score: 0.7483
#
#    • "The new administration, led by the Democratic Party, proposed
# a tax reform bill, sparking intense debates across the country."
#      🔹 ↔ Similarity with → "Protests erupted in major cities such as New York and Los Angeles
# as activists demanded a more transparent legislative process."
#        ✅ Score: 0.7725
#
#
# 📌 Cluster 3:
#    • "A highly anticipated Hollywood blockbuster produced by Warner Bros. broke box office
# records, earning the highest opening weekend revenue."
#      🔹 ↔ Similarity with → "The film’s success boosted the
# studio’s stock prices on the New York Stock Exchange, reflecting strong investor confidence."
#        ✅ Score: 0.7805
#
#    • "A highly anticipated Hollywood blockbuster produced by Warner Bros. broke box office
# records, earning the highest opening weekend revenue."
#      🔹 ↔ Similarity with → "Fans praised lead actor Leonardo DiCaprio’s performance, fueling awards season speculation."
#        ✅ Score: 0.7227
#
#    • "A highly anticipated Hollywood blockbuster produced by Warner Bros. broke box office
# records, earning the highest opening weekend revenue."
#      🔹 ↔ Similarity with → "Meanwhile, director Christopher Nolan announced a sequel, promising an even more thrilling
# storyline."
#        ✅ Score: 0.7100
#
#    • "The film’s success boosted the
# studio’s stock prices on the New York Stock Exchange, reflecting strong investor confidence."
#      🔹 ↔ Similarity with → "Fans praised lead actor Leonardo DiCaprio’s performance, fueling awards season speculation."
#        ✅ Score: 0.6844
#
#    • "The film’s success boosted the
# studio’s stock prices on the New York Stock Exchange, reflecting strong investor confidence."
#      🔹 ↔ Similarity with → "Meanwhile, director Christopher Nolan announced a sequel, promising an even more thrilling
# storyline."
#        ✅ Score: 0.6776
#
#    • "Fans praised lead actor Leonardo DiCaprio’s performance, fueling awards season speculation."
#      🔹 ↔ Similarity with → "Meanwhile, director Christopher Nolan announced a sequel, promising an even more thrilling
# storyline."
#        ✅ Score: 0.7771
#
#
# 📌 Cluster 4:
#    • "Opposition leaders from the
# Republican Party called for revisions, claiming the bill favors large corporations like Amazon
# and Google over citizens."
#      🔹 ↔ Similarity with → "Analysts from ESPN praised the coach's strategic
# substitutions, crediting them for the late-game turnaround."
#        ✅ Score: 0.6993
#
#    • "Opposition leaders from the
# Republican Party called for revisions, claiming the bill favors large corporations like Amazon
# and Google over citizens."
#      🔹 ↔ Similarity with → "However, privacy concerns emerged as critics
# questioned data security measures implemented by Meta and Google."
#        ✅ Score: 0.8012
#
#    • "Opposition leaders from the
# Republican Party called for revisions, claiming the bill favors large corporations like Amazon
# and Google over citizens."
#      🔹 ↔ Similarity with → "Regulators from the
# European Union launched an inquiry into potential ethical implications of AI integration."
#        ✅ Score: 0.7339
#
#    • "Opposition leaders from the
# Republican Party called for revisions, claiming the bill favors large corporations like Amazon
# and Google over citizens."
#      🔹 ↔ Similarity with → "In
# response, Apple pledged to implement stricter policies to address public concerns."
#        ✅ Score: 0.7845
#
#    • "Analysts from ESPN praised the coach's strategic
# substitutions, crediting them for the late-game turnaround."
#      🔹 ↔ Similarity with → "However, privacy concerns emerged as critics
# questioned data security measures implemented by Meta and Google."
#        ✅ Score: 0.6606
#
#    • "Analysts from ESPN praised the coach's strategic
# substitutions, crediting them for the late-game turnaround."
#      🔹 ↔ Similarity with → "Regulators from the
# European Union launched an inquiry into potential ethical implications of AI integration."
#        ✅ Score: 0.6380
#
#    • "Analysts from ESPN praised the coach's strategic
# substitutions, crediting them for the late-game turnaround."
#      🔹 ↔ Similarity with → "In
# response, Apple pledged to implement stricter policies to address public concerns."
#        ✅ Score: 0.6471
#
#    • "However, privacy concerns emerged as critics
# questioned data security measures implemented by Meta and Google."
#      🔹 ↔ Similarity with → "Regulators from the
# European Union launched an inquiry into potential ethical implications of AI integration."
#        ✅ Score: 0.7876
#
#    • "However, privacy concerns emerged as critics
# questioned data security measures implemented by Meta and Google."
#      🔹 ↔ Similarity with → "In
# response, Apple pledged to implement stricter policies to address public concerns."
#        ✅ Score: 0.8189
#
#    • "Regulators from the
# European Union launched an inquiry into potential ethical implications of AI integration."
#      🔹 ↔ Similarity with → "In
# response, Apple pledged to implement stricter policies to address public concerns."
#        ✅ Score: 0.7613
#
#
# 📌 Cluster 5:
#    • "Streaming platforms like Netflix and Disney+ rushed to acquire exclusive rights,
# intensifying competition in the industry."
#      🔹 ↔ Similarity with → "Apple unveiled an AI-powered device at its headquarters in Cupertino, California,
# revolutionizing personal computing."
#        ✅ Score: 0.6781
#
#    • "Streaming platforms like Netflix and Disney+ rushed to acquire exclusive rights,
# intensifying competition in the industry."
#      🔹 ↔ Similarity with → "The innovation spurred interest from global investors,
# causing Apple’s stock to surge on the Nasdaq."
#        ✅ Score: 0.7847
#
#    • "Streaming platforms like Netflix and Disney+ rushed to acquire exclusive rights,
# intensifying competition in the industry."
#      🔹 ↔ Similarity with → "Tech giants like Microsoft and Tesla reported record earnings, causing a sharp rise in the stock
# market."
#        ✅ Score: 0.8227
#
#    • "Streaming platforms like Netflix and Disney+ rushed to acquire exclusive rights,
# intensifying competition in the industry."
#      🔹 ↔ Similarity with → "However, market analysts from Bloomberg warned of potential volatility due to
# rising interest rates set by the Federal Reserve."
#        ✅ Score: 0.7139
#
#    • "Streaming platforms like Netflix and Disney+ rushed to acquire exclusive rights,
# intensifying competition in the industry."
#      🔹 ↔ Similarity with → "The energy sector saw mixed results, with oil
# prices fluctuating amid geopolitical tensions in the Middle East."
#        ✅ Score: 0.7757
#
#    • "Streaming platforms like Netflix and Disney+ rushed to acquire exclusive rights,
# intensifying competition in the industry."
#      🔹 ↔ Similarity with → "Despite uncertainties,
# renewable energy stocks, including Tesla and NextEra Energy, continued to experience steady
# growth."
#        ✅ Score: 0.7805
#
#    • "Apple unveiled an AI-powered device at its headquarters in Cupertino, California,
# revolutionizing personal computing."
#      🔹 ↔ Similarity with → "The innovation spurred interest from global investors,
# causing Apple’s stock to surge on the Nasdaq."
#        ✅ Score: 0.7327
#
#    • "Apple unveiled an AI-powered device at its headquarters in Cupertino, California,
# revolutionizing personal computing."
#      🔹 ↔ Similarity with → "Tech giants like Microsoft and Tesla reported record earnings, causing a sharp rise in the stock
# market."
#        ✅ Score: 0.7273
#
#    • "Apple unveiled an AI-powered device at its headquarters in Cupertino, California,
# revolutionizing personal computing."
#      🔹 ↔ Similarity with → "However, market analysts from Bloomberg warned of potential volatility due to
# rising interest rates set by the Federal Reserve."
#        ✅ Score: 0.5734
#
#    • "Apple unveiled an AI-powered device at its headquarters in Cupertino, California,
# revolutionizing personal computing."
#      🔹 ↔ Similarity with → "The energy sector saw mixed results, with oil
# prices fluctuating amid geopolitical tensions in the Middle East."
#        ✅ Score: 0.6100
#
#    • "Apple unveiled an AI-powered device at its headquarters in Cupertino, California,
# revolutionizing personal computing."
#      🔹 ↔ Similarity with → "Despite uncertainties,
# renewable energy stocks, including Tesla and NextEra Energy, continued to experience steady
# growth."
#        ✅ Score: 0.7022
#
#    • "The innovation spurred interest from global investors,
# causing Apple’s stock to surge on the Nasdaq."
#      🔹 ↔ Similarity with → "Tech giants like Microsoft and Tesla reported record earnings, causing a sharp rise in the stock
# market."
#        ✅ Score: 0.8199
#
#    • "The innovation spurred interest from global investors,
# causing Apple’s stock to surge on the Nasdaq."
#      🔹 ↔ Similarity with → "However, market analysts from Bloomberg warned of potential volatility due to
# rising interest rates set by the Federal Reserve."
#        ✅ Score: 0.7918
#
#    • "The innovation spurred interest from global investors,
# causing Apple’s stock to surge on the Nasdaq."
#      🔹 ↔ Similarity with → "The energy sector saw mixed results, with oil
# prices fluctuating amid geopolitical tensions in the Middle East."
#        ✅ Score: 0.6743
#
#    • "The innovation spurred interest from global investors,
# causing Apple’s stock to surge on the Nasdaq."
#      🔹 ↔ Similarity with → "Despite uncertainties,
# renewable energy stocks, including Tesla and NextEra Energy, continued to experience steady
# growth."
#        ✅ Score: 0.7648
#
#    • "Tech giants like Microsoft and Tesla reported record earnings, causing a sharp rise in the stock
# market."
#      🔹 ↔ Similarity with → "However, market analysts from Bloomberg warned of potential volatility due to
# rising interest rates set by the Federal Reserve."
#        ✅ Score: 0.8056
#
#    • "Tech giants like Microsoft and Tesla reported record earnings, causing a sharp rise in the stock
# market."
#      🔹 ↔ Similarity with → "The energy sector saw mixed results, with oil
# prices fluctuating amid geopolitical tensions in the Middle East."
#        ✅ Score: 0.8006
#
#    • "Tech giants like Microsoft and Tesla reported record earnings, causing a sharp rise in the stock
# market."
#      🔹 ↔ Similarity with → "Despite uncertainties,
# renewable energy stocks, including Tesla and NextEra Energy, continued to experience steady
# growth."
#        ✅ Score: 0.8515
#
#    • "However, market analysts from Bloomberg warned of potential volatility due to
# rising interest rates set by the Federal Reserve."
#      🔹 ↔ Similarity with → "The energy sector saw mixed results, with oil
# prices fluctuating amid geopolitical tensions in the Middle East."
#        ✅ Score: 0.7582
#
#    • "However, market analysts from Bloomberg warned of potential volatility due to
# rising interest rates set by the Federal Reserve."
#      🔹 ↔ Similarity with → "Despite uncertainties,
# renewable energy stocks, including Tesla and NextEra Energy, continued to experience steady
# growth."
#        ✅ Score: 0.7769
#
#    • "The energy sector saw mixed results, with oil
# prices fluctuating amid geopolitical tensions in the Middle East."
#      🔹 ↔ Similarity with → "Despite uncertainties,
# renewable energy stocks, including Tesla and NextEra Energy, continued to experience steady
# growth."
#        ✅ Score: 0.8201
#
#
# 🔹 Pairwise Sentence Similarity Scores:
#    🔵 Sentence 1: "The recent parliamentary elections in Washington, D.C. resulted in a coalition government,
# shifting the balance of power."
#    🔵 Sentence 2: "The new administration, led by the Democratic Party, proposed
# a tax reform bill, sparking intense debates across the country."
#      🔹 ✅ Similarity Score: 0.8025
#
#    🔵 Sentence 1: "The recent parliamentary elections in Washington, D.C. resulted in a coalition government,
# shifting the balance of power."
#    🔵 Sentence 2: "Opposition leaders from the
# Republican Party called for revisions, claiming the bill favors large corporations like Amazon
# and Google over citizens."
#      🔹 ✅ Similarity Score: 0.7382
#
#    🔵 Sentence 1: "The recent parliamentary elections in Washington, D.C. resulted in a coalition government,
# shifting the balance of power."
#    🔵 Sentence 2: "Protests erupted in major cities such as New York and Los Angeles
# as activists demanded a more transparent legislative process."
#      🔹 ✅ Similarity Score: 0.7483
#
#    🔵 Sentence 1: "The recent parliamentary elections in Washington, D.C. resulted in a coalition government,
# shifting the balance of power."
#    🔵 Sentence 2: "The national football team of Brazil won a dramatic final match in Rio de Janeiro, clinching
# their first championship title in years."
#      🔹 ✅ Similarity Score: 0.6439
#
#    🔵 Sentence 1: "The recent parliamentary elections in Washington, D.C. resulted in a coalition government,
# shifting the balance of power."
#    🔵 Sentence 2: "Analysts from ESPN praised the coach's strategic
# substitutions, crediting them for the late-game turnaround."
#      🔹 ✅ Similarity Score: 0.5788
#
#    🔵 Sentence 1: "The recent parliamentary elections in Washington, D.C. resulted in a coalition government,
# shifting the balance of power."
#    🔵 Sentence 2: "Meanwhile, FIFA announced an
# expansion plan, adding two new teams next season."
#      🔹 ✅ Similarity Score: 0.6466
#
#    🔵 Sentence 1: "The recent parliamentary elections in Washington, D.C. resulted in a coalition government,
# shifting the balance of power."
#    🔵 Sentence 2: "A highly anticipated Hollywood blockbuster produced by Warner Bros. broke box office
# records, earning the highest opening weekend revenue."
#      🔹 ✅ Similarity Score: 0.5979
#
#    🔵 Sentence 1: "The recent parliamentary elections in Washington, D.C. resulted in a coalition government,
# shifting the balance of power."
#    🔵 Sentence 2: "The film’s success boosted the
# studio’s stock prices on the New York Stock Exchange, reflecting strong investor confidence."
#      🔹 ✅ Similarity Score: 0.6114
#
#    🔵 Sentence 1: "The recent parliamentary elections in Washington, D.C. resulted in a coalition government,
# shifting the balance of power."
#    🔵 Sentence 2: "Fans praised lead actor Leonardo DiCaprio’s performance, fueling awards season speculation."
#      🔹 ✅ Similarity Score: 0.6126
#
#    🔵 Sentence 1: "The recent parliamentary elections in Washington, D.C. resulted in a coalition government,
# shifting the balance of power."
#    🔵 Sentence 2: "Meanwhile, director Christopher Nolan announced a sequel, promising an even more thrilling
# storyline."
#      🔹 ✅ Similarity Score: 0.6167
#
#    🔵 Sentence 1: "The recent parliamentary elections in Washington, D.C. resulted in a coalition government,
# shifting the balance of power."
#    🔵 Sentence 2: "Streaming platforms like Netflix and Disney+ rushed to acquire exclusive rights,
# intensifying competition in the industry."
#      🔹 ✅ Similarity Score: 0.6834
#
#    🔵 Sentence 1: "The recent parliamentary elections in Washington, D.C. resulted in a coalition government,
# shifting the balance of power."
#    🔵 Sentence 2: "Apple unveiled an AI-powered device at its headquarters in Cupertino, California,
# revolutionizing personal computing."
#      🔹 ✅ Similarity Score: 0.5922
#
#    🔵 Sentence 1: "The recent parliamentary elections in Washington, D.C. resulted in a coalition government,
# shifting the balance of power."
#    🔵 Sentence 2: "The innovation spurred interest from global investors,
# causing Apple’s stock to surge on the Nasdaq."
#      🔹 ✅ Similarity Score: 0.5918
#
#    🔵 Sentence 1: "The recent parliamentary elections in Washington, D.C. resulted in a coalition government,
# shifting the balance of power."
#    🔵 Sentence 2: "However, privacy concerns emerged as critics
# questioned data security measures implemented by Meta and Google."
#      🔹 ✅ Similarity Score: 0.6439
#
#    🔵 Sentence 1: "The recent parliamentary elections in Washington, D.C. resulted in a coalition government,
# shifting the balance of power."
#    🔵 Sentence 2: "Regulators from the
# European Union launched an inquiry into potential ethical implications of AI integration."
#      🔹 ✅ Similarity Score: 0.6470
#
#    🔵 Sentence 1: "The recent parliamentary elections in Washington, D.C. resulted in a coalition government,
# shifting the balance of power."
#    🔵 Sentence 2: "In
# response, Apple pledged to implement stricter policies to address public concerns."
#      🔹 ✅ Similarity Score: 0.6842
#
#    🔵 Sentence 1: "The recent parliamentary elections in Washington, D.C. resulted in a coalition government,
# shifting the balance of power."
#    🔵 Sentence 2: "Tech giants like Microsoft and Tesla reported record earnings, causing a sharp rise in the stock
# market."
#      🔹 ✅ Similarity Score: 0.6836
#
#    🔵 Sentence 1: "The recent parliamentary elections in Washington, D.C. resulted in a coalition government,
# shifting the balance of power."
#    🔵 Sentence 2: "However, market analysts from Bloomberg warned of potential volatility due to
# rising interest rates set by the Federal Reserve."
#      🔹 ✅ Similarity Score: 0.6187
#
#    🔵 Sentence 1: "The recent parliamentary elections in Washington, D.C. resulted in a coalition government,
# shifting the balance of power."
#    🔵 Sentence 2: "The energy sector saw mixed results, with oil
# prices fluctuating amid geopolitical tensions in the Middle East."
#      🔹 ✅ Similarity Score: 0.7370
#
#    🔵 Sentence 1: "The recent parliamentary elections in Washington, D.C. resulted in a coalition government,
# shifting the balance of power."
#    🔵 Sentence 2: "Despite uncertainties,
# renewable energy stocks, including Tesla and NextEra Energy, continued to experience steady
# growth."
#      🔹 ✅ Similarity Score: 0.7086
#
#    🔵 Sentence 1: "The new administration, led by the Democratic Party, proposed
# a tax reform bill, sparking intense debates across the country."
#    🔵 Sentence 2: "Opposition leaders from the
# Republican Party called for revisions, claiming the bill favors large corporations like Amazon
# and Google over citizens."
#      🔹 ✅ Similarity Score: 0.8012
#
#    🔵 Sentence 1: "The new administration, led by the Democratic Party, proposed
# a tax reform bill, sparking intense debates across the country."
#    🔵 Sentence 2: "Protests erupted in major cities such as New York and Los Angeles
# as activists demanded a more transparent legislative process."
#      🔹 ✅ Similarity Score: 0.7725
#
#    🔵 Sentence 1: "The new administration, led by the Democratic Party, proposed
# a tax reform bill, sparking intense debates across the country."
#    🔵 Sentence 2: "The national football team of Brazil won a dramatic final match in Rio de Janeiro, clinching
# their first championship title in years."
#      🔹 ✅ Similarity Score: 0.6530
#
#    🔵 Sentence 1: "The new administration, led by the Democratic Party, proposed
# a tax reform bill, sparking intense debates across the country."
#    🔵 Sentence 2: "Analysts from ESPN praised the coach's strategic
# substitutions, crediting them for the late-game turnaround."
#      🔹 ✅ Similarity Score: 0.6553
#
#    🔵 Sentence 1: "The new administration, led by the Democratic Party, proposed
# a tax reform bill, sparking intense debates across the country."
#    🔵 Sentence 2: "Meanwhile, FIFA announced an
# expansion plan, adding two new teams next season."
#      🔹 ✅ Similarity Score: 0.6738
#
#    🔵 Sentence 1: "The new administration, led by the Democratic Party, proposed
# a tax reform bill, sparking intense debates across the country."
#    🔵 Sentence 2: "A highly anticipated Hollywood blockbuster produced by Warner Bros. broke box office
# records, earning the highest opening weekend revenue."
#      🔹 ✅ Similarity Score: 0.6383
#
#    🔵 Sentence 1: "The new administration, led by the Democratic Party, proposed
# a tax reform bill, sparking intense debates across the country."
#    🔵 Sentence 2: "The film’s success boosted the
# studio’s stock prices on the New York Stock Exchange, reflecting strong investor confidence."
#      🔹 ✅ Similarity Score: 0.6936
#
#    🔵 Sentence 1: "The new administration, led by the Democratic Party, proposed
# a tax reform bill, sparking intense debates across the country."
#    🔵 Sentence 2: "Fans praised lead actor Leonardo DiCaprio’s performance, fueling awards season speculation."
#      🔹 ✅ Similarity Score: 0.6511
#
#    🔵 Sentence 1: "The new administration, led by the Democratic Party, proposed
# a tax reform bill, sparking intense debates across the country."
#    🔵 Sentence 2: "Meanwhile, director Christopher Nolan announced a sequel, promising an even more thrilling
# storyline."
#      🔹 ✅ Similarity Score: 0.6332
#
#    🔵 Sentence 1: "The new administration, led by the Democratic Party, proposed
# a tax reform bill, sparking intense debates across the country."
#    🔵 Sentence 2: "Streaming platforms like Netflix and Disney+ rushed to acquire exclusive rights,
# intensifying competition in the industry."
#      🔹 ✅ Similarity Score: 0.6899
#
#    🔵 Sentence 1: "The new administration, led by the Democratic Party, proposed
# a tax reform bill, sparking intense debates across the country."
#    🔵 Sentence 2: "Apple unveiled an AI-powered device at its headquarters in Cupertino, California,
# revolutionizing personal computing."
#      🔹 ✅ Similarity Score: 0.6084
#
#    🔵 Sentence 1: "The new administration, led by the Democratic Party, proposed
# a tax reform bill, sparking intense debates across the country."
#    🔵 Sentence 2: "The innovation spurred interest from global investors,
# causing Apple’s stock to surge on the Nasdaq."
#      🔹 ✅ Similarity Score: 0.6211
#
#    🔵 Sentence 1: "The new administration, led by the Democratic Party, proposed
# a tax reform bill, sparking intense debates across the country."
#    🔵 Sentence 2: "However, privacy concerns emerged as critics
# questioned data security measures implemented by Meta and Google."
#      🔹 ✅ Similarity Score: 0.6778
#
#    🔵 Sentence 1: "The new administration, led by the Democratic Party, proposed
# a tax reform bill, sparking intense debates across the country."
#    🔵 Sentence 2: "Regulators from the
# European Union launched an inquiry into potential ethical implications of AI integration."
#      🔹 ✅ Similarity Score: 0.6368
#
#    🔵 Sentence 1: "The new administration, led by the Democratic Party, proposed
# a tax reform bill, sparking intense debates across the country."
#    🔵 Sentence 2: "In
# response, Apple pledged to implement stricter policies to address public concerns."
#      🔹 ✅ Similarity Score: 0.6913
#
#    🔵 Sentence 1: "The new administration, led by the Democratic Party, proposed
# a tax reform bill, sparking intense debates across the country."
#    🔵 Sentence 2: "Tech giants like Microsoft and Tesla reported record earnings, causing a sharp rise in the stock
# market."
#      🔹 ✅ Similarity Score: 0.7060
#
#    🔵 Sentence 1: "The new administration, led by the Democratic Party, proposed
# a tax reform bill, sparking intense debates across the country."
#    🔵 Sentence 2: "However, market analysts from Bloomberg warned of potential volatility due to
# rising interest rates set by the Federal Reserve."
#      🔹 ✅ Similarity Score: 0.6126
#
#    🔵 Sentence 1: "The new administration, led by the Democratic Party, proposed
# a tax reform bill, sparking intense debates across the country."
#    🔵 Sentence 2: "The energy sector saw mixed results, with oil
# prices fluctuating amid geopolitical tensions in the Middle East."
#      🔹 ✅ Similarity Score: 0.7177
#
#    🔵 Sentence 1: "The new administration, led by the Democratic Party, proposed
# a tax reform bill, sparking intense debates across the country."
#    🔵 Sentence 2: "Despite uncertainties,
# renewable energy stocks, including Tesla and NextEra Energy, continued to experience steady
# growth."
#      🔹 ✅ Similarity Score: 0.6910
#
#    🔵 Sentence 1: "Opposition leaders from the
# Republican Party called for revisions, claiming the bill favors large corporations like Amazon
# and Google over citizens."
#    🔵 Sentence 2: "Protests erupted in major cities such as New York and Los Angeles
# as activists demanded a more transparent legislative process."
#      🔹 ✅ Similarity Score: 0.8321
#
#    🔵 Sentence 1: "Opposition leaders from the
# Republican Party called for revisions, claiming the bill favors large corporations like Amazon
# and Google over citizens."
#    🔵 Sentence 2: "The national football team of Brazil won a dramatic final match in Rio de Janeiro, clinching
# their first championship title in years."
#      🔹 ✅ Similarity Score: 0.5720
#
#    🔵 Sentence 1: "Opposition leaders from the
# Republican Party called for revisions, claiming the bill favors large corporations like Amazon
# and Google over citizens."
#    🔵 Sentence 2: "Analysts from ESPN praised the coach's strategic
# substitutions, crediting them for the late-game turnaround."
#      🔹 ✅ Similarity Score: 0.6993
#
#    🔵 Sentence 1: "Opposition leaders from the
# Republican Party called for revisions, claiming the bill favors large corporations like Amazon
# and Google over citizens."
#    🔵 Sentence 2: "Meanwhile, FIFA announced an
# expansion plan, adding two new teams next season."
#      🔹 ✅ Similarity Score: 0.6583
#
#    🔵 Sentence 1: "Opposition leaders from the
# Republican Party called for revisions, claiming the bill favors large corporations like Amazon
# and Google over citizens."
#    🔵 Sentence 2: "A highly anticipated Hollywood blockbuster produced by Warner Bros. broke box office
# records, earning the highest opening weekend revenue."
#      🔹 ✅ Similarity Score: 0.6119
#
#    🔵 Sentence 1: "Opposition leaders from the
# Republican Party called for revisions, claiming the bill favors large corporations like Amazon
# and Google over citizens."
#    🔵 Sentence 2: "The film’s success boosted the
# studio’s stock prices on the New York Stock Exchange, reflecting strong investor confidence."
#      🔹 ✅ Similarity Score: 0.6414
#
#    🔵 Sentence 1: "Opposition leaders from the
# Republican Party called for revisions, claiming the bill favors large corporations like Amazon
# and Google over citizens."
#    🔵 Sentence 2: "Fans praised lead actor Leonardo DiCaprio’s performance, fueling awards season speculation."
#      🔹 ✅ Similarity Score: 0.6840
#
#    🔵 Sentence 1: "Opposition leaders from the
# Republican Party called for revisions, claiming the bill favors large corporations like Amazon
# and Google over citizens."
#    🔵 Sentence 2: "Meanwhile, director Christopher Nolan announced a sequel, promising an even more thrilling
# storyline."
#      🔹 ✅ Similarity Score: 0.6312
#
#    🔵 Sentence 1: "Opposition leaders from the
# Republican Party called for revisions, claiming the bill favors large corporations like Amazon
# and Google over citizens."
#    🔵 Sentence 2: "Streaming platforms like Netflix and Disney+ rushed to acquire exclusive rights,
# intensifying competition in the industry."
#      🔹 ✅ Similarity Score: 0.7475
#
#    🔵 Sentence 1: "Opposition leaders from the
# Republican Party called for revisions, claiming the bill favors large corporations like Amazon
# and Google over citizens."
#    🔵 Sentence 2: "Apple unveiled an AI-powered device at its headquarters in Cupertino, California,
# revolutionizing personal computing."
#      🔹 ✅ Similarity Score: 0.6616
#
#    🔵 Sentence 1: "Opposition leaders from the
# Republican Party called for revisions, claiming the bill favors large corporations like Amazon
# and Google over citizens."
#    🔵 Sentence 2: "The innovation spurred interest from global investors,
# causing Apple’s stock to surge on the Nasdaq."
#      🔹 ✅ Similarity Score: 0.6882
#
#    🔵 Sentence 1: "Opposition leaders from the
# Republican Party called for revisions, claiming the bill favors large corporations like Amazon
# and Google over citizens."
#    🔵 Sentence 2: "However, privacy concerns emerged as critics
# questioned data security measures implemented by Meta and Google."
#      🔹 ✅ Similarity Score: 0.8012
#
#    🔵 Sentence 1: "Opposition leaders from the
# Republican Party called for revisions, claiming the bill favors large corporations like Amazon
# and Google over citizens."
#    🔵 Sentence 2: "Regulators from the
# European Union launched an inquiry into potential ethical implications of AI integration."
#      🔹 ✅ Similarity Score: 0.7339
#
#    🔵 Sentence 1: "Opposition leaders from the
# Republican Party called for revisions, claiming the bill favors large corporations like Amazon
# and Google over citizens."
#    🔵 Sentence 2: "In
# response, Apple pledged to implement stricter policies to address public concerns."
#      🔹 ✅ Similarity Score: 0.7845
#
#    🔵 Sentence 1: "Opposition leaders from the
# Republican Party called for revisions, claiming the bill favors large corporations like Amazon
# and Google over citizens."
#    🔵 Sentence 2: "Tech giants like Microsoft and Tesla reported record earnings, causing a sharp rise in the stock
# market."
#      🔹 ✅ Similarity Score: 0.7426
#
#    🔵 Sentence 1: "Opposition leaders from the
# Republican Party called for revisions, claiming the bill favors large corporations like Amazon
# and Google over citizens."
#    🔵 Sentence 2: "However, market analysts from Bloomberg warned of potential volatility due to
# rising interest rates set by the Federal Reserve."
#      🔹 ✅ Similarity Score: 0.6768
#
#    🔵 Sentence 1: "Opposition leaders from the
# Republican Party called for revisions, claiming the bill favors large corporations like Amazon
# and Google over citizens."
#    🔵 Sentence 2: "The energy sector saw mixed results, with oil
# prices fluctuating amid geopolitical tensions in the Middle East."
#      🔹 ✅ Similarity Score: 0.6862
#
#    🔵 Sentence 1: "Opposition leaders from the
# Republican Party called for revisions, claiming the bill favors large corporations like Amazon
# and Google over citizens."
#    🔵 Sentence 2: "Despite uncertainties,
# renewable energy stocks, including Tesla and NextEra Energy, continued to experience steady
# growth."
#      🔹 ✅ Similarity Score: 0.7253
#
#    🔵 Sentence 1: "Protests erupted in major cities such as New York and Los Angeles
# as activists demanded a more transparent legislative process."
#    🔵 Sentence 2: "The national football team of Brazil won a dramatic final match in Rio de Janeiro, clinching
# their first championship title in years."
#      🔹 ✅ Similarity Score: 0.6189
#
#    🔵 Sentence 1: "Protests erupted in major cities such as New York and Los Angeles
# as activists demanded a more transparent legislative process."
#    🔵 Sentence 2: "Analysts from ESPN praised the coach's strategic
# substitutions, crediting them for the late-game turnaround."
#      🔹 ✅ Similarity Score: 0.6524
#
#    🔵 Sentence 1: "Protests erupted in major cities such as New York and Los Angeles
# as activists demanded a more transparent legislative process."
#    🔵 Sentence 2: "Meanwhile, FIFA announced an
# expansion plan, adding two new teams next season."
#      🔹 ✅ Similarity Score: 0.6294
#
#    🔵 Sentence 1: "Protests erupted in major cities such as New York and Los Angeles
# as activists demanded a more transparent legislative process."
#    🔵 Sentence 2: "A highly anticipated Hollywood blockbuster produced by Warner Bros. broke box office
# records, earning the highest opening weekend revenue."
#      🔹 ✅ Similarity Score: 0.6121
#
#    🔵 Sentence 1: "Protests erupted in major cities such as New York and Los Angeles
# as activists demanded a more transparent legislative process."
#    🔵 Sentence 2: "The film’s success boosted the
# studio’s stock prices on the New York Stock Exchange, reflecting strong investor confidence."
#      🔹 ✅ Similarity Score: 0.6331
#
#    🔵 Sentence 1: "Protests erupted in major cities such as New York and Los Angeles
# as activists demanded a more transparent legislative process."
#    🔵 Sentence 2: "Fans praised lead actor Leonardo DiCaprio’s performance, fueling awards season speculation."
#      🔹 ✅ Similarity Score: 0.6929
#
#    🔵 Sentence 1: "Protests erupted in major cities such as New York and Los Angeles
# as activists demanded a more transparent legislative process."
#    🔵 Sentence 2: "Meanwhile, director Christopher Nolan announced a sequel, promising an even more thrilling
# storyline."
#      🔹 ✅ Similarity Score: 0.6188
#
#    🔵 Sentence 1: "Protests erupted in major cities such as New York and Los Angeles
# as activists demanded a more transparent legislative process."
#    🔵 Sentence 2: "Streaming platforms like Netflix and Disney+ rushed to acquire exclusive rights,
# intensifying competition in the industry."
#      🔹 ✅ Similarity Score: 0.7376
#
#    🔵 Sentence 1: "Protests erupted in major cities such as New York and Los Angeles
# as activists demanded a more transparent legislative process."
#    🔵 Sentence 2: "Apple unveiled an AI-powered device at its headquarters in Cupertino, California,
# revolutionizing personal computing."
#      🔹 ✅ Similarity Score: 0.6712
#
#    🔵 Sentence 1: "Protests erupted in major cities such as New York and Los Angeles
# as activists demanded a more transparent legislative process."
#    🔵 Sentence 2: "The innovation spurred interest from global investors,
# causing Apple’s stock to surge on the Nasdaq."
#      🔹 ✅ Similarity Score: 0.6664
#
#    🔵 Sentence 1: "Protests erupted in major cities such as New York and Los Angeles
# as activists demanded a more transparent legislative process."
#    🔵 Sentence 2: "However, privacy concerns emerged as critics
# questioned data security measures implemented by Meta and Google."
#      🔹 ✅ Similarity Score: 0.7562
#
#    🔵 Sentence 1: "Protests erupted in major cities such as New York and Los Angeles
# as activists demanded a more transparent legislative process."
#    🔵 Sentence 2: "Regulators from the
# European Union launched an inquiry into potential ethical implications of AI integration."
#      🔹 ✅ Similarity Score: 0.7215
#
#    🔵 Sentence 1: "Protests erupted in major cities such as New York and Los Angeles
# as activists demanded a more transparent legislative process."
#    🔵 Sentence 2: "In
# response, Apple pledged to implement stricter policies to address public concerns."
#      🔹 ✅ Similarity Score: 0.7613
#
#    🔵 Sentence 1: "Protests erupted in major cities such as New York and Los Angeles
# as activists demanded a more transparent legislative process."
#    🔵 Sentence 2: "Tech giants like Microsoft and Tesla reported record earnings, causing a sharp rise in the stock
# market."
#      🔹 ✅ Similarity Score: 0.7382
#
#    🔵 Sentence 1: "Protests erupted in major cities such as New York and Los Angeles
# as activists demanded a more transparent legislative process."
#    🔵 Sentence 2: "However, market analysts from Bloomberg warned of potential volatility due to
# rising interest rates set by the Federal Reserve."
#      🔹 ✅ Similarity Score: 0.6382
#
#    🔵 Sentence 1: "Protests erupted in major cities such as New York and Los Angeles
# as activists demanded a more transparent legislative process."
#    🔵 Sentence 2: "The energy sector saw mixed results, with oil
# prices fluctuating amid geopolitical tensions in the Middle East."
#      🔹 ✅ Similarity Score: 0.7043
#
#    🔵 Sentence 1: "Protests erupted in major cities such as New York and Los Angeles
# as activists demanded a more transparent legislative process."
#    🔵 Sentence 2: "Despite uncertainties,
# renewable energy stocks, including Tesla and NextEra Energy, continued to experience steady
# growth."
#      🔹 ✅ Similarity Score: 0.7056
#
#    🔵 Sentence 1: "The national football team of Brazil won a dramatic final match in Rio de Janeiro, clinching
# their first championship title in years."
#    🔵 Sentence 2: "Analysts from ESPN praised the coach's strategic
# substitutions, crediting them for the late-game turnaround."
#      🔹 ✅ Similarity Score: 0.5747
#
#    🔵 Sentence 1: "The national football team of Brazil won a dramatic final match in Rio de Janeiro, clinching
# their first championship title in years."
#    🔵 Sentence 2: "Meanwhile, FIFA announced an
# expansion plan, adding two new teams next season."
#      🔹 ✅ Similarity Score: 0.7261
#
#    🔵 Sentence 1: "The national football team of Brazil won a dramatic final match in Rio de Janeiro, clinching
# their first championship title in years."
#    🔵 Sentence 2: "A highly anticipated Hollywood blockbuster produced by Warner Bros. broke box office
# records, earning the highest opening weekend revenue."
#      🔹 ✅ Similarity Score: 0.6172
#
#    🔵 Sentence 1: "The national football team of Brazil won a dramatic final match in Rio de Janeiro, clinching
# their first championship title in years."
#    🔵 Sentence 2: "The film’s success boosted the
# studio’s stock prices on the New York Stock Exchange, reflecting strong investor confidence."
#      🔹 ✅ Similarity Score: 0.6165
#
#    🔵 Sentence 1: "The national football team of Brazil won a dramatic final match in Rio de Janeiro, clinching
# their first championship title in years."
#    🔵 Sentence 2: "Fans praised lead actor Leonardo DiCaprio’s performance, fueling awards season speculation."
#      🔹 ✅ Similarity Score: 0.6138
#
#    🔵 Sentence 1: "The national football team of Brazil won a dramatic final match in Rio de Janeiro, clinching
# their first championship title in years."
#    🔵 Sentence 2: "Meanwhile, director Christopher Nolan announced a sequel, promising an even more thrilling
# storyline."
#      🔹 ✅ Similarity Score: 0.5876
#
#    🔵 Sentence 1: "The national football team of Brazil won a dramatic final match in Rio de Janeiro, clinching
# their first championship title in years."
#    🔵 Sentence 2: "Streaming platforms like Netflix and Disney+ rushed to acquire exclusive rights,
# intensifying competition in the industry."
#      🔹 ✅ Similarity Score: 0.6267
#
#    🔵 Sentence 1: "The national football team of Brazil won a dramatic final match in Rio de Janeiro, clinching
# their first championship title in years."
#    🔵 Sentence 2: "Apple unveiled an AI-powered device at its headquarters in Cupertino, California,
# revolutionizing personal computing."
#      🔹 ✅ Similarity Score: 0.6476
#
#    🔵 Sentence 1: "The national football team of Brazil won a dramatic final match in Rio de Janeiro, clinching
# their first championship title in years."
#    🔵 Sentence 2: "The innovation spurred interest from global investors,
# causing Apple’s stock to surge on the Nasdaq."
#      🔹 ✅ Similarity Score: 0.5562
#
#    🔵 Sentence 1: "The national football team of Brazil won a dramatic final match in Rio de Janeiro, clinching
# their first championship title in years."
#    🔵 Sentence 2: "However, privacy concerns emerged as critics
# questioned data security measures implemented by Meta and Google."
#      🔹 ✅ Similarity Score: 0.5351
#
#    🔵 Sentence 1: "The national football team of Brazil won a dramatic final match in Rio de Janeiro, clinching
# their first championship title in years."
#    🔵 Sentence 2: "Regulators from the
# European Union launched an inquiry into potential ethical implications of AI integration."
#      🔹 ✅ Similarity Score: 0.5682
#
#    🔵 Sentence 1: "The national football team of Brazil won a dramatic final match in Rio de Janeiro, clinching
# their first championship title in years."
#    🔵 Sentence 2: "In
# response, Apple pledged to implement stricter policies to address public concerns."
#      🔹 ✅ Similarity Score: 0.5528
#
#    🔵 Sentence 1: "The national football team of Brazil won a dramatic final match in Rio de Janeiro, clinching
# their first championship title in years."
#    🔵 Sentence 2: "Tech giants like Microsoft and Tesla reported record earnings, causing a sharp rise in the stock
# market."
#      🔹 ✅ Similarity Score: 0.6410
#
#    🔵 Sentence 1: "The national football team of Brazil won a dramatic final match in Rio de Janeiro, clinching
# their first championship title in years."
#    🔵 Sentence 2: "However, market analysts from Bloomberg warned of potential volatility due to
# rising interest rates set by the Federal Reserve."
#      🔹 ✅ Similarity Score: 0.5029
#
#    🔵 Sentence 1: "The national football team of Brazil won a dramatic final match in Rio de Janeiro, clinching
# their first championship title in years."
#    🔵 Sentence 2: "The energy sector saw mixed results, with oil
# prices fluctuating amid geopolitical tensions in the Middle East."
#      🔹 ✅ Similarity Score: 0.6424
#
#    🔵 Sentence 1: "The national football team of Brazil won a dramatic final match in Rio de Janeiro, clinching
# their first championship title in years."
#    🔵 Sentence 2: "Despite uncertainties,
# renewable energy stocks, including Tesla and NextEra Energy, continued to experience steady
# growth."
#      🔹 ✅ Similarity Score: 0.6425
#
#    🔵 Sentence 1: "Analysts from ESPN praised the coach's strategic
# substitutions, crediting them for the late-game turnaround."
#    🔵 Sentence 2: "Meanwhile, FIFA announced an
# expansion plan, adding two new teams next season."
#      🔹 ✅ Similarity Score: 0.6371
#
#    🔵 Sentence 1: "Analysts from ESPN praised the coach's strategic
# substitutions, crediting them for the late-game turnaround."
#    🔵 Sentence 2: "A highly anticipated Hollywood blockbuster produced by Warner Bros. broke box office
# records, earning the highest opening weekend revenue."
#      🔹 ✅ Similarity Score: 0.5773
#
#    🔵 Sentence 1: "Analysts from ESPN praised the coach's strategic
# substitutions, crediting them for the late-game turnaround."
#    🔵 Sentence 2: "The film’s success boosted the
# studio’s stock prices on the New York Stock Exchange, reflecting strong investor confidence."
#      🔹 ✅ Similarity Score: 0.5911
#
#    🔵 Sentence 1: "Analysts from ESPN praised the coach's strategic
# substitutions, crediting them for the late-game turnaround."
#    🔵 Sentence 2: "Fans praised lead actor Leonardo DiCaprio’s performance, fueling awards season speculation."
#      🔹 ✅ Similarity Score: 0.7304
#
#    🔵 Sentence 1: "Analysts from ESPN praised the coach's strategic
# substitutions, crediting them for the late-game turnaround."
#    🔵 Sentence 2: "Meanwhile, director Christopher Nolan announced a sequel, promising an even more thrilling
# storyline."
#      🔹 ✅ Similarity Score: 0.6145
#
#    🔵 Sentence 1: "Analysts from ESPN praised the coach's strategic
# substitutions, crediting them for the late-game turnaround."
#    🔵 Sentence 2: "Streaming platforms like Netflix and Disney+ rushed to acquire exclusive rights,
# intensifying competition in the industry."
#      🔹 ✅ Similarity Score: 0.6644
#
#    🔵 Sentence 1: "Analysts from ESPN praised the coach's strategic
# substitutions, crediting them for the late-game turnaround."
#    🔵 Sentence 2: "Apple unveiled an AI-powered device at its headquarters in Cupertino, California,
# revolutionizing personal computing."
#      🔹 ✅ Similarity Score: 0.5533
#
#    🔵 Sentence 1: "Analysts from ESPN praised the coach's strategic
# substitutions, crediting them for the late-game turnaround."
#    🔵 Sentence 2: "The innovation spurred interest from global investors,
# causing Apple’s stock to surge on the Nasdaq."
#      🔹 ✅ Similarity Score: 0.6079
#
#    🔵 Sentence 1: "Analysts from ESPN praised the coach's strategic
# substitutions, crediting them for the late-game turnaround."
#    🔵 Sentence 2: "However, privacy concerns emerged as critics
# questioned data security measures implemented by Meta and Google."
#      🔹 ✅ Similarity Score: 0.6606
#
#    🔵 Sentence 1: "Analysts from ESPN praised the coach's strategic
# substitutions, crediting them for the late-game turnaround."
#    🔵 Sentence 2: "Regulators from the
# European Union launched an inquiry into potential ethical implications of AI integration."
#      🔹 ✅ Similarity Score: 0.6380
#
#    🔵 Sentence 1: "Analysts from ESPN praised the coach's strategic
# substitutions, crediting them for the late-game turnaround."
#    🔵 Sentence 2: "In
# response, Apple pledged to implement stricter policies to address public concerns."
#      🔹 ✅ Similarity Score: 0.6471
#
#    🔵 Sentence 1: "Analysts from ESPN praised the coach's strategic
# substitutions, crediting them for the late-game turnaround."
#    🔵 Sentence 2: "Tech giants like Microsoft and Tesla reported record earnings, causing a sharp rise in the stock
# market."
#      🔹 ✅ Similarity Score: 0.6299
#
#    🔵 Sentence 1: "Analysts from ESPN praised the coach's strategic
# substitutions, crediting them for the late-game turnaround."
#    🔵 Sentence 2: "However, market analysts from Bloomberg warned of potential volatility due to
# rising interest rates set by the Federal Reserve."
#      🔹 ✅ Similarity Score: 0.6169
#
#    🔵 Sentence 1: "Analysts from ESPN praised the coach's strategic
# substitutions, crediting them for the late-game turnaround."
#    🔵 Sentence 2: "The energy sector saw mixed results, with oil
# prices fluctuating amid geopolitical tensions in the Middle East."
#      🔹 ✅ Similarity Score: 0.6429
#
#    🔵 Sentence 1: "Analysts from ESPN praised the coach's strategic
# substitutions, crediting them for the late-game turnaround."
#    🔵 Sentence 2: "Despite uncertainties,
# renewable energy stocks, including Tesla and NextEra Energy, continued to experience steady
# growth."
#      🔹 ✅ Similarity Score: 0.6292
#
#    🔵 Sentence 1: "Meanwhile, FIFA announced an
# expansion plan, adding two new teams next season."
#    🔵 Sentence 2: "A highly anticipated Hollywood blockbuster produced by Warner Bros. broke box office
# records, earning the highest opening weekend revenue."
#      🔹 ✅ Similarity Score: 0.5958
#
#    🔵 Sentence 1: "Meanwhile, FIFA announced an
# expansion plan, adding two new teams next season."
#    🔵 Sentence 2: "The film’s success boosted the
# studio’s stock prices on the New York Stock Exchange, reflecting strong investor confidence."
#      🔹 ✅ Similarity Score: 0.6138
#
#    🔵 Sentence 1: "Meanwhile, FIFA announced an
# expansion plan, adding two new teams next season."
#    🔵 Sentence 2: "Fans praised lead actor Leonardo DiCaprio’s performance, fueling awards season speculation."
#      🔹 ✅ Similarity Score: 0.6188
#
#    🔵 Sentence 1: "Meanwhile, FIFA announced an
# expansion plan, adding two new teams next season."
#    🔵 Sentence 2: "Meanwhile, director Christopher Nolan announced a sequel, promising an even more thrilling
# storyline."
#      🔹 ✅ Similarity Score: 0.6881
#
#    🔵 Sentence 1: "Meanwhile, FIFA announced an
# expansion plan, adding two new teams next season."
#    🔵 Sentence 2: "Streaming platforms like Netflix and Disney+ rushed to acquire exclusive rights,
# intensifying competition in the industry."
#      🔹 ✅ Similarity Score: 0.6797
#
#    🔵 Sentence 1: "Meanwhile, FIFA announced an
# expansion plan, adding two new teams next season."
#    🔵 Sentence 2: "Apple unveiled an AI-powered device at its headquarters in Cupertino, California,
# revolutionizing personal computing."
#      🔹 ✅ Similarity Score: 0.6148
#
#    🔵 Sentence 1: "Meanwhile, FIFA announced an
# expansion plan, adding two new teams next season."
#    🔵 Sentence 2: "The innovation spurred interest from global investors,
# causing Apple’s stock to surge on the Nasdaq."
#      🔹 ✅ Similarity Score: 0.5959
#
#    🔵 Sentence 1: "Meanwhile, FIFA announced an
# expansion plan, adding two new teams next season."
#    🔵 Sentence 2: "However, privacy concerns emerged as critics
# questioned data security measures implemented by Meta and Google."
#      🔹 ✅ Similarity Score: 0.6317
#
#    🔵 Sentence 1: "Meanwhile, FIFA announced an
# expansion plan, adding two new teams next season."
#    🔵 Sentence 2: "Regulators from the
# European Union launched an inquiry into potential ethical implications of AI integration."
#      🔹 ✅ Similarity Score: 0.6624
#
#    🔵 Sentence 1: "Meanwhile, FIFA announced an
# expansion plan, adding two new teams next season."
#    🔵 Sentence 2: "In
# response, Apple pledged to implement stricter policies to address public concerns."
#      🔹 ✅ Similarity Score: 0.6676
#
# ...
# storyline."
#    🔵 Sentence 2: "Apple unveiled an AI-powered device at its headquarters in Cupertino, California,
# revolutionizing personal computing."
#      🔹 ✅ Similarity Score: 0.6382
#
#    🔵 Sentence 1: "Meanwhile, director Christopher Nolan announced a sequel, promising an even more thrilling
# storyline."
#    🔵 Sentence 2: "The innovation spurred interest from global investors,
# causing Apple’s stock to surge on the Nasdaq."
#      🔹 ✅ Similarity Score: 0.6055
#
#    🔵 Sentence 1: "Meanwhile, director Christopher Nolan announced a sequel, promising an even more thrilling
# storyline."
#    🔵 Sentence 2: "However, privacy concerns emerged as critics
# questioned data security measures implemented by Meta and Google."
#      🔹 ✅ Similarity Score: 0.6246
#
#    🔵 Sentence 1: "Meanwhile, director Christopher Nolan announced a sequel, promising an even more thrilling
# storyline."
#    🔵 Sentence 2: "Regulators from the
# European Union launched an inquiry into potential ethical implications of AI integration."
#      🔹 ✅ Similarity Score: 0.6096
#
#    🔵 Sentence 1: "Meanwhile, director Christopher Nolan announced a sequel, promising an even more thrilling
# storyline."
#    🔵 Sentence 2: "In
# response, Apple pledged to implement stricter policies to address public concerns."
#      🔹 ✅ Similarity Score: 0.6759
#
#    🔵 Sentence 1: "Meanwhile, director Christopher Nolan announced a sequel, promising an even more thrilling
# storyline."
#    🔵 Sentence 2: "Tech giants like Microsoft and Tesla reported record earnings, causing a sharp rise in the stock
# market."
#      🔹 ✅ Similarity Score: 0.6280
#
#    🔵 Sentence 1: "Meanwhile, director Christopher Nolan announced a sequel, promising an even more thrilling
# storyline."
#    🔵 Sentence 2: "However, market analysts from Bloomberg warned of potential volatility due to
# rising interest rates set by the Federal Reserve."
#      🔹 ✅ Similarity Score: 0.5563
#
#    🔵 Sentence 1: "Meanwhile, director Christopher Nolan announced a sequel, promising an even more thrilling
# storyline."
#    🔵 Sentence 2: "The energy sector saw mixed results, with oil
# prices fluctuating amid geopolitical tensions in the Middle East."
#      🔹 ✅ Similarity Score: 0.6339
#
#    🔵 Sentence 1: "Meanwhile, director Christopher Nolan announced a sequel, promising an even more thrilling
# storyline."
#    🔵 Sentence 2: "Despite uncertainties,
# renewable energy stocks, including Tesla and NextEra Energy, continued to experience steady
# growth."
#      🔹 ✅ Similarity Score: 0.6600
#
#    🔵 Sentence 1: "Streaming platforms like Netflix and Disney+ rushed to acquire exclusive rights,
# intensifying competition in the industry."
#    🔵 Sentence 2: "Apple unveiled an AI-powered device at its headquarters in Cupertino, California,
# revolutionizing personal computing."
#      🔹 ✅ Similarity Score: 0.6781
#
#    🔵 Sentence 1: "Streaming platforms like Netflix and Disney+ rushed to acquire exclusive rights,
# intensifying competition in the industry."
#    🔵 Sentence 2: "The innovation spurred interest from global investors,
# causing Apple’s stock to surge on the Nasdaq."
#      🔹 ✅ Similarity Score: 0.7847
#
#    🔵 Sentence 1: "Streaming platforms like Netflix and Disney+ rushed to acquire exclusive rights,
# intensifying competition in the industry."
#    🔵 Sentence 2: "However, privacy concerns emerged as critics
# questioned data security measures implemented by Meta and Google."
#      🔹 ✅ Similarity Score: 0.7614
#
#    🔵 Sentence 1: "Streaming platforms like Netflix and Disney+ rushed to acquire exclusive rights,
# intensifying competition in the industry."
#    🔵 Sentence 2: "Regulators from the
# European Union launched an inquiry into potential ethical implications of AI integration."
#      🔹 ✅ Similarity Score: 0.7045
#
#    🔵 Sentence 1: "Streaming platforms like Netflix and Disney+ rushed to acquire exclusive rights,
# intensifying competition in the industry."
#    🔵 Sentence 2: "In
# response, Apple pledged to implement stricter policies to address public concerns."
#      🔹 ✅ Similarity Score: 0.7478
#
#    🔵 Sentence 1: "Streaming platforms like Netflix and Disney+ rushed to acquire exclusive rights,
# intensifying competition in the industry."
#    🔵 Sentence 2: "Tech giants like Microsoft and Tesla reported record earnings, causing a sharp rise in the stock
# market."
#      🔹 ✅ Similarity Score: 0.8227
#
#    🔵 Sentence 1: "Streaming platforms like Netflix and Disney+ rushed to acquire exclusive rights,
# intensifying competition in the industry."
#    🔵 Sentence 2: "However, market analysts from Bloomberg warned of potential volatility due to
# rising interest rates set by the Federal Reserve."
#      🔹 ✅ Similarity Score: 0.7139
#
#    🔵 Sentence 1: "Streaming platforms like Netflix and Disney+ rushed to acquire exclusive rights,
# intensifying competition in the industry."
#    🔵 Sentence 2: "The energy sector saw mixed results, with oil
# prices fluctuating amid geopolitical tensions in the Middle East."
#      🔹 ✅ Similarity Score: 0.7757
#
#    🔵 Sentence 1: "Streaming platforms like Netflix and Disney+ rushed to acquire exclusive rights,
# intensifying competition in the industry."
#    🔵 Sentence 2: "Despite uncertainties,
# renewable energy stocks, including Tesla and NextEra Energy, continued to experience steady
# growth."
#      🔹 ✅ Similarity Score: 0.7805
#
#    🔵 Sentence 1: "Apple unveiled an AI-powered device at its headquarters in Cupertino, California,
# revolutionizing personal computing."
#    🔵 Sentence 2: "The innovation spurred interest from global investors,
# causing Apple’s stock to surge on the Nasdaq."
#      🔹 ✅ Similarity Score: 0.7327
#
#    🔵 Sentence 1: "Apple unveiled an AI-powered device at its headquarters in Cupertino, California,
# revolutionizing personal computing."
#    🔵 Sentence 2: "However, privacy concerns emerged as critics
# questioned data security measures implemented by Meta and Google."
#      🔹 ✅ Similarity Score: 0.7025
#
#    🔵 Sentence 1: "Apple unveiled an AI-powered device at its headquarters in Cupertino, California,
# revolutionizing personal computing."
#    🔵 Sentence 2: "Regulators from the
# European Union launched an inquiry into potential ethical implications of AI integration."
#      🔹 ✅ Similarity Score: 0.6733
#
#    🔵 Sentence 1: "Apple unveiled an AI-powered device at its headquarters in Cupertino, California,
# revolutionizing personal computing."
#    🔵 Sentence 2: "In
# response, Apple pledged to implement stricter policies to address public concerns."
#      🔹 ✅ Similarity Score: 0.6976
#
#    🔵 Sentence 1: "Apple unveiled an AI-powered device at its headquarters in Cupertino, California,
# revolutionizing personal computing."
#    🔵 Sentence 2: "Tech giants like Microsoft and Tesla reported record earnings, causing a sharp rise in the stock
# market."
#      🔹 ✅ Similarity Score: 0.7273
#
#    🔵 Sentence 1: "Apple unveiled an AI-powered device at its headquarters in Cupertino, California,
# revolutionizing personal computing."
#    🔵 Sentence 2: "However, market analysts from Bloomberg warned of potential volatility due to
# rising interest rates set by the Federal Reserve."
#      🔹 ✅ Similarity Score: 0.5734
#
#    🔵 Sentence 1: "Apple unveiled an AI-powered device at its headquarters in Cupertino, California,
# revolutionizing personal computing."
#    🔵 Sentence 2: "The energy sector saw mixed results, with oil
# prices fluctuating amid geopolitical tensions in the Middle East."
#      🔹 ✅ Similarity Score: 0.6100
#
#    🔵 Sentence 1: "Apple unveiled an AI-powered device at its headquarters in Cupertino, California,
# revolutionizing personal computing."
#    🔵 Sentence 2: "Despite uncertainties,
# renewable energy stocks, including Tesla and NextEra Energy, continued to experience steady
# growth."
#      🔹 ✅ Similarity Score: 0.7022
#
#    🔵 Sentence 1: "The innovation spurred interest from global investors,
# causing Apple’s stock to surge on the Nasdaq."
#    🔵 Sentence 2: "However, privacy concerns emerged as critics
# questioned data security measures implemented by Meta and Google."
#      🔹 ✅ Similarity Score: 0.7426
#
#    🔵 Sentence 1: "The innovation spurred interest from global investors,
# causing Apple’s stock to surge on the Nasdaq."
#    🔵 Sentence 2: "Regulators from the
# European Union launched an inquiry into potential ethical implications of AI integration."
#      🔹 ✅ Similarity Score: 0.6849
#
#    🔵 Sentence 1: "The innovation spurred interest from global investors,
# causing Apple’s stock to surge on the Nasdaq."
#    🔵 Sentence 2: "In
# response, Apple pledged to implement stricter policies to address public concerns."
#      🔹 ✅ Similarity Score: 0.6924
#
#    🔵 Sentence 1: "The innovation spurred interest from global investors,
# causing Apple’s stock to surge on the Nasdaq."
#    🔵 Sentence 2: "Tech giants like Microsoft and Tesla reported record earnings, causing a sharp rise in the stock
# market."
#      🔹 ✅ Similarity Score: 0.8199
#
#    🔵 Sentence 1: "The innovation spurred interest from global investors,
# causing Apple’s stock to surge on the Nasdaq."
#    🔵 Sentence 2: "However, market analysts from Bloomberg warned of potential volatility due to
# rising interest rates set by the Federal Reserve."
#      🔹 ✅ Similarity Score: 0.7918
#
#    🔵 Sentence 1: "The innovation spurred interest from global investors,
# causing Apple’s stock to surge on the Nasdaq."
#    🔵 Sentence 2: "The energy sector saw mixed results, with oil
# prices fluctuating amid geopolitical tensions in the Middle East."
#      🔹 ✅ Similarity Score: 0.6743
#
#    🔵 Sentence 1: "The innovation spurred interest from global investors,
# causing Apple’s stock to surge on the Nasdaq."
#    🔵 Sentence 2: "Despite uncertainties,
# renewable energy stocks, including Tesla and NextEra Energy, continued to experience steady
# growth."
#      🔹 ✅ Similarity Score: 0.7648
#
#    🔵 Sentence 1: "However, privacy concerns emerged as critics
# questioned data security measures implemented by Meta and Google."
#    🔵 Sentence 2: "Regulators from the
# European Union launched an inquiry into potential ethical implications of AI integration."
#      🔹 ✅ Similarity Score: 0.7876
#
#    🔵 Sentence 1: "However, privacy concerns emerged as critics
# questioned data security measures implemented by Meta and Google."
#    🔵 Sentence 2: "In
# response, Apple pledged to implement stricter policies to address public concerns."
#      🔹 ✅ Similarity Score: 0.8189
#
#    🔵 Sentence 1: "However, privacy concerns emerged as critics
# questioned data security measures implemented by Meta and Google."
#    🔵 Sentence 2: "Tech giants like Microsoft and Tesla reported record earnings, causing a sharp rise in the stock
# market."
#      🔹 ✅ Similarity Score: 0.7566
#
#    🔵 Sentence 1: "However, privacy concerns emerged as critics
# questioned data security measures implemented by Meta and Google."
#    🔵 Sentence 2: "However, market analysts from Bloomberg warned of potential volatility due to
# rising interest rates set by the Federal Reserve."
#      🔹 ✅ Similarity Score: 0.7060
#
#    🔵 Sentence 1: "However, privacy concerns emerged as critics
# questioned data security measures implemented by Meta and Google."
#    🔵 Sentence 2: "The energy sector saw mixed results, with oil
# prices fluctuating amid geopolitical tensions in the Middle East."
#      🔹 ✅ Similarity Score: 0.6750
#
#    🔵 Sentence 1: "However, privacy concerns emerged as critics
# questioned data security measures implemented by Meta and Google."
#    🔵 Sentence 2: "Despite uncertainties,
# renewable energy stocks, including Tesla and NextEra Energy, continued to experience steady
# growth."
#      🔹 ✅ Similarity Score: 0.7429
#
#    🔵 Sentence 1: "Regulators from the
# European Union launched an inquiry into potential ethical implications of AI integration."
#    🔵 Sentence 2: "In
# response, Apple pledged to implement stricter policies to address public concerns."
#      🔹 ✅ Similarity Score: 0.7613
#
#    🔵 Sentence 1: "Regulators from the
# European Union launched an inquiry into potential ethical implications of AI integration."
#    🔵 Sentence 2: "Tech giants like Microsoft and Tesla reported record earnings, causing a sharp rise in the stock
# market."
#      🔹 ✅ Similarity Score: 0.7204
#
#    🔵 Sentence 1: "Regulators from the
# European Union launched an inquiry into potential ethical implications of AI integration."
#    🔵 Sentence 2: "However, market analysts from Bloomberg warned of potential volatility due to
# rising interest rates set by the Federal Reserve."
#      🔹 ✅ Similarity Score: 0.6984
#
#    🔵 Sentence 1: "Regulators from the
# European Union launched an inquiry into potential ethical implications of AI integration."
#    🔵 Sentence 2: "The energy sector saw mixed results, with oil
# prices fluctuating amid geopolitical tensions in the Middle East."
#      🔹 ✅ Similarity Score: 0.7105
#
#    🔵 Sentence 1: "Regulators from the
# European Union launched an inquiry into potential ethical implications of AI integration."
#    🔵 Sentence 2: "Despite uncertainties,
# renewable energy stocks, including Tesla and NextEra Energy, continued to experience steady
# growth."
#      🔹 ✅ Similarity Score: 0.7148
#
#    🔵 Sentence 1: "In
# response, Apple pledged to implement stricter policies to address public concerns."
#    🔵 Sentence 2: "Tech giants like Microsoft and Tesla reported record earnings, causing a sharp rise in the stock
# market."
#      🔹 ✅ Similarity Score: 0.7279
#
#    🔵 Sentence 1: "In
# response, Apple pledged to implement stricter policies to address public concerns."
#    🔵 Sentence 2: "However, market analysts from Bloomberg warned of potential volatility due to
# rising interest rates set by the Federal Reserve."
#      🔹 ✅ Similarity Score: 0.7086
#
#    🔵 Sentence 1: "In
# response, Apple pledged to implement stricter policies to address public concerns."
#    🔵 Sentence 2: "The energy sector saw mixed results, with oil
# prices fluctuating amid geopolitical tensions in the Middle East."
#      🔹 ✅ Similarity Score: 0.7147
#
#    🔵 Sentence 1: "In
# response, Apple pledged to implement stricter policies to address public concerns."
#    🔵 Sentence 2: "Despite uncertainties,
# renewable energy stocks, including Tesla and NextEra Energy, continued to experience steady
# growth."
#      🔹 ✅ Similarity Score: 0.7574
#
#    🔵 Sentence 1: "Tech giants like Microsoft and Tesla reported record earnings, causing a sharp rise in the stock
# market."
#    🔵 Sentence 2: "However, market analysts from Bloomberg warned of potential volatility due to
# rising interest rates set by the Federal Reserve."
#      🔹 ✅ Similarity Score: 0.8056
#
#    🔵 Sentence 1: "Tech giants like Microsoft and Tesla reported record earnings, causing a sharp rise in the stock
# market."
#    🔵 Sentence 2: "The energy sector saw mixed results, with oil
# prices fluctuating amid geopolitical tensions in the Middle East."
#      🔹 ✅ Similarity Score: 0.8006
#
#    🔵 Sentence 1: "Tech giants like Microsoft and Tesla reported record earnings, causing a sharp rise in the stock
# market."
#    🔵 Sentence 2: "Despite uncertainties,
# renewable energy stocks, including Tesla and NextEra Energy, continued to experience steady
# growth."
#      🔹 ✅ Similarity Score: 0.8515
#
#    🔵 Sentence 1: "However, market analysts from Bloomberg warned of potential volatility due to
# rising interest rates set by the Federal Reserve."
#    🔵 Sentence 2: "The energy sector saw mixed results, with oil
# prices fluctuating amid geopolitical tensions in the Middle East."
#      🔹 ✅ Similarity Score: 0.7582
#
#    🔵 Sentence 1: "However, market analysts from Bloomberg warned of potential volatility due to
# rising interest rates set by the Federal Reserve."
#    🔵 Sentence 2: "Despite uncertainties,
# renewable energy stocks, including Tesla and NextEra Energy, continued to experience steady
# growth."
#      🔹 ✅ Similarity Score: 0.7769
#
#    🔵 Sentence 1: "The energy sector saw mixed results, with oil
# prices fluctuating amid geopolitical tensions in the Middle East."
#    🔵 Sentence 2: "Despite uncertainties,
# renewable energy stocks, including Tesla and NextEra Energy, continued to experience steady
# growth."
#      🔹 ✅ Similarity Score: 0.8201

# %%
def find_centroid_sentence(cluster_sentences, cluster_embeddings):
    similarity_matrix = cosine_similarity(cluster_embeddings)
    centroid_idx = np.argmax(np.mean(similarity_matrix, axis=1))
    return cluster_sentences[centroid_idx], centroid_idx, similarity_matrix  # Returns 3 values

# %% [markdown]
# # **CLUSTER SUMMARY**

# %%
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# Function to compute cosine similarity between all sentence embeddings in a cluster
def compute_cosine_similarities(embeddings):
    return cosine_similarity(embeddings)

# Function to find the most central (most similar) sentence in each cluster
def find_cluster_summary(cluster_sentences, cluster_embeddings):
    if len(cluster_sentences) == 1:
        return cluster_sentences[0]  # If only one sentence in cluster, return it directly

    # Compute cosine similarities between sentences in the same cluster
    cosine_sim = compute_cosine_similarities(cluster_embeddings)

    # Calculate the average similarity for each sentence in the cluster
    avg_similarities = cosine_sim.mean(axis=1)

    # Find the index of the sentence with the highest average similarity
    summary_index = np.argmax(avg_similarities)

    # Return the most central sentence as the summary
    return cluster_sentences[summary_index]

# Step: Print the summary for each cluster based on cosine similarity
print("\n🔹 Cluster Summaries Based on Cosine Similarity:\n")
cluster_summaries = {}  # Dictionary to store summaries
num_clusters=5
for cluster_id in range(num_clusters):
    cluster_sentences = cluster_dict[cluster_id]

    if cluster_sentences:  # Ensure cluster is not empty
        # Get embeddings for the sentences in the current cluster
        cluster_embeddings = np.array(cluster_embeddings_dict[cluster_id])

        # Get the summary sentence for this cluster
        summary_sentence = find_cluster_summary(cluster_sentences, cluster_embeddings)

        cluster_summaries[cluster_id] = summary_sentence  # Store summary

        # Print the summary
        print(f"\n📌 Cluster {cluster_id + 1} Summary:")
        print("-", summary_sentence)

# Optional: Store summaries in a list if needed
final_summary = list(cluster_summaries.values())
# Out:
# 🔹 Cluster Summaries Based on Cosine Similarity:
#
#
# 📌 Cluster 1 Summary:
# - The national football team of Brazil won a dramatic final match in Rio de Janeiro, clinching
# their first championship title in years.
#
# 📌 Cluster 2 Summary:
# - The new administration, led by the Democratic Party, proposed
# a tax reform bill, sparking intense debates across the country.
#
# 📌 Cluster 3 Summary:
# - A highly anticipated Hollywood blockbuster produced by Warner Bros. broke box office
# records, earning the highest opening weekend revenue.
#
# 📌 Cluster 4 Summary:
# - However, privacy concerns emerged as critics
# questioned data security measures implemented by Meta and Google.
#
# 📌 Cluster 5 Summary:
# - Tech giants like Microsoft and Tesla reported record earnings, causing a sharp rise in the stock
# market.

# %% [markdown]
# # **EUCLIDEAN DISTANCE FOR CLUSTERING**

# %%
from scipy.spatial.distance import euclidean
import numpy as np

# Step: Compute Euclidean Distance of Sentences from Centroids
print("\n🔹 Euclidean Distances of Sentences from Cluster Centroids:")

for cluster_id in range(num_clusters):
    if len(cluster_dict[cluster_id]) > 0:
        # Find centroid sentence and its index (ignore similarity_matrix)
        centroid_sentence, centroid_idx, _ = find_centroid_sentence(
            cluster_dict[cluster_id], np.array(cluster_embeddings_dict[cluster_id])
        )
        centroid_embedding = np.array(cluster_embeddings_dict[cluster_id])[centroid_idx]

        print(f"\n📌 Cluster {cluster_id + 1} Centroid Sentence:")
        print(f"   - {centroid_sentence}\n")

        # Calculate Euclidean distance of each sentence from the centroid
        distances = []
        for i, sentence in enumerate(cluster_dict[cluster_id]):
            distance = euclidean(centroid_embedding, cluster_embeddings_dict[cluster_id][i])
            distances.append((sentence, distance))

        # Sort sentences by distance from the centroid
        distances.sort(key=lambda x: x[1])

        print("   Sentences sorted by distance from centroid:")
        for sent, dist in distances:
            print(f"   - {sent} (Distance: {dist:.4f})")
# Out:
# 🔹 Euclidean Distances of Sentences from Cluster Centroids:
#
# 📌 Cluster 1 Centroid Sentence:
#    - The national football team of Brazil won a dramatic final match in Rio de Janeiro, clinching
# their first championship title in years.
#
#    Sentences sorted by distance from centroid:
#    - The national football team of Brazil won a dramatic final match in Rio de Janeiro, clinching
# their first championship title in years. (Distance: 0.0000)
#    - Meanwhile, FIFA announced an
# expansion plan, adding two new teams next season. (Distance: 7.0771)
#
# 📌 Cluster 2 Centroid Sentence:
#    - The new administration, led by the Democratic Party, proposed
# a tax reform bill, sparking intense debates across the country.
#
#    Sentences sorted by distance from centroid:
#    - The new administration, led by the Democratic Party, proposed
# a tax reform bill, sparking intense debates across the country. (Distance: 0.0000)
#    - The recent parliamentary elections in Washington, D.C. resulted in a coalition government,
# shifting the balance of power. (Distance: 6.0682)
#    - Protests erupted in major cities such as New York and Los Angeles
# as activists demanded a more transparent legislative process. (Distance: 6.6792)
#
# 📌 Cluster 3 Centroid Sentence:
#    - A highly anticipated Hollywood blockbuster produced by Warner Bros. broke box office
# records, earning the highest opening weekend revenue.
#
#    Sentences sorted by distance from centroid:
#    - A highly anticipated Hollywood blockbuster produced by Warner Bros. broke box office
# records, earning the highest opening weekend revenue. (Distance: 0.0000)
#    - The film’s success boosted the
# studio’s stock prices on the New York Stock Exchange, reflecting strong investor confidence. (Distance: 6.3609)
#    - Fans praised lead actor Leonardo DiCaprio’s performance, fueling awards season speculation. (Distance: 7.3123)
#    - Meanwhile, director Christopher Nolan announced a sequel, promising an even more thrilling
# storyline. (Distance: 7.4504)
#
# 📌 Cluster 4 Centroid Sentence:
#    - However, privacy concerns emerged as critics
# questioned data security measures implemented by Meta and Google.
#
#    Sentences sorted by distance from centroid:
#    - However, privacy concerns emerged as critics
# questioned data security measures implemented by Meta and Google. (Distance: 0.0000)
#    - Opposition leaders from the
# Republican Party called for revisions, claiming the bill favors large corporations like Amazon
# and Google over citizens. (Distance: 5.6767)
#    - In
# response, Apple pledged to implement stricter policies to address public concerns. (Distance: 5.8333)
#    - Regulators from the
# European Union launched an inquiry into potential ethical implications of AI integration. (Distance: 6.0777)
#    - Analysts from ESPN praised the coach's strategic
# substitutions, crediting them for the late-game turnaround. (Distance: 7.9185)
#
# 📌 Cluster 5 Centroid Sentence:
#    - Tech giants like Microsoft and Tesla reported record earnings, causing a sharp rise in the stock
# market.
#
#    Sentences sorted by distance from centroid:
#    - Tech giants like Microsoft and Tesla reported record earnings, causing a sharp rise in the stock
# market. (Distance: 0.0000)
#    - Despite uncertainties,
# renewable energy stocks, including Tesla and NextEra Energy, continued to experience steady
# growth. (Distance: 5.4439)
#    - The innovation spurred interest from global investors,
# causing Apple’s stock to surge on the Nasdaq. (Distance: 5.7890)
#    - Streaming platforms like Netflix and Disney+ rushed to acquire exclusive rights,
# intensifying competition in the industry. (Distance: 5.8538)
#    - However, market analysts from Bloomberg warned of potential volatility due to
# rising interest rates set by the Federal Reserve. (Distance: 6.3029)
#    - The energy sector saw mixed results, with oil
# prices fluctuating amid geopolitical tensions in the Middle East. (Distance: 6.6033)
#    - Apple unveiled an AI-powered device at its headquarters in Cupertino, California,
# revolutionizing personal computing. (Distance: 7.0823)

# %% [markdown]
# # **CLUSTER ANALYSIS**

# %%
# Extract the centroid sentence of Cluster 4
cluster_id = 3  # Cluster 4 (zero-based index)
centroid_sentence, centroid_idx, _ = find_centroid_sentence(
    cluster_dict[cluster_id], np.array(sentence_embeddings[clusters == cluster_id])
)

# Tokenize and get word embeddings for each word in the centroid sentence
tokens = tokenizer.tokenize(centroid_sentence)
inputs = tokenizer(centroid_sentence, return_tensors="pt", padding=True, truncation=True, max_length=512)

with torch.no_grad():
    outputs = model(**inputs)

# Extract embeddings for each token
word_embeddings = outputs.last_hidden_state.squeeze(0)  # Shape: (num_tokens, embedding_dim)

# Print word embeddings
print(f"\n🔹 Word Embeddings for Each Token in Centroid Sentence of Cluster 4:\n")
for token, embedding in zip(tokens, word_embeddings):
    print(f"Token: {token}\nEmbedding: {embedding.numpy()}\n")
# Out:
# 🔹 Word Embeddings for Each Token in Centroid Sentence of Cluster 4:
#
# Token: however
# Embedding: [-3.46439213e-01 -1.51526749e-01 -5.01923561e-01  2.48411775e-01
#  -5.89512467e-01  1.78395405e-01  5.63737333e-01  3.09803672e-02
#   1.67283744e-01  2.78489858e-01 -1.15326405e-01 -2.28878736e-01
#  -9.54669788e-02  8.59639049e-01  1.69955015e-01 -1.62474141e-01
#  -3.40217620e-01  6.07969284e-01  5.95120668e-01  2.09461376e-01
#  -1.53136134e-01 -2.31477737e-01  7.86720216e-02 -6.18944969e-03
#  -9.95777249e-02 -5.48874140e-01  2.65589114e-02 -5.19021153e-01
#  -9.00311768e-02  2.59114504e-01 -6.88675046e-01  2.20381320e-01
#  -6.20640397e-01 -1.95054412e-01  5.05710125e-01 -2.82753080e-01
#  -4.98129845e-01 -5.90378791e-02  1.47453085e-01  4.40258980e-02
#  -7.65779197e-01 -7.39695907e-01 -3.57899554e-02  2.28708878e-01
#  -7.47926831e-02  3.32332969e-01 -3.45462561e+00  1.65664759e-02
#  -4.30441827e-01  9.57752317e-02  2.68383138e-02  1.63775921e-01
#   3.21890175e-01  4.89583880e-01 -1.00370355e-01  2.45601833e-01
#  -2.43930966e-01 -8.49277452e-02  2.60541081e-01  2.24516854e-01
#  -1.15768358e-01  2.77567744e-01  3.09997708e-01 -5.33960640e-01
#  -6.53732359e-01  1.68000385e-01 -4.23003167e-01  9.48096693e-01
#   2.71859288e-01 -1.38512686e-01 -2.26113796e-01  6.08781688e-02
#  -1.75440609e-01  2.38018483e-01 -4.26158346e-02 -1.30217358e-01
#  -4.23526913e-01 -4.79712546e-01  3.19325298e-01  4.38365221e-01
#  -6.72737300e-01  1.78586036e-01 -1.61924392e-01 -3.23451608e-01
#   4.02534187e-01  3.91450226e-02 -5.77670753e-01  7.53679797e-02
#  -2.44416118e-01 -3.02710861e-01  1.93964109e-01  6.22955449e-02
#  -1.27196148e-01  1.60797626e-01  3.24098498e-01  4.38387811e-01
#   5.93515873e-01  2.68793970e-01 -1.07401773e-01  3.46977413e-02
#   7.75486007e-02  1.00955389e-01  1.78325385e-01  1.00304037e-01
#  -1.73093989e-01  2.39688680e-01 -4.11673307e-01 -3.87445837e-01
#   9.05728340e-02 -3.15375566e-01  1.34428114e-01 -2.93505341e-01
#   1.12715319e-01  2.59596892e-02  1.52249619e-01  3.88148464e-02
#  -8.83438364e-02 -4.10551518e-01 -1.21770196e-01  1.94754392e-01
#  -9.71847698e-02 -1.25379547e-01  2.12849036e-01 -5.79303443e-01
#   1.35009885e-01 -2.72489071e-01 -2.42986381e-01  4.66292016e-02]

# %% [markdown]
# # **MODIFICATIONS IN MY CODE**

# %%
import spacy
import pdfplumber
import re
import nltk
import numpy as np
import torch
from transformers import BertTokenizer, BertModel
from sklearn.cluster import KMeans

# Download NLTK tokenizer
nltk.download('punkt')

# Load spaCy English model
nlp = spacy.load("en_core_web_sm")

# Function to extract text from PDF
def extract_text_from_pdf(pdf_path):
    with pdfplumber.open(pdf_path) as pdf:
        text = " ".join([page.extract_text() for page in pdf.pages if page.extract_text()])
    return text

# Function to clean and tokenize text into sentences
def preprocess_text(text):
    text = re.sub(r'\n+', ' ', text)  # Remove newlines
    sentences = nltk.sent_tokenize(text)  # Split into sentences
    return sentences

# Function to filter sentences that contain Named Entities
def filter_sentences_with_entities(sentences):
    filtered_sentences = []
    for sentence in sentences:
        doc = nlp(sentence)
        if len(doc.ents) > 0:  # Keep only sentences with Named Entities
            filtered_sentences.append(sentence)
    return filtered_sentences

# Load BERT tokenizer and model
tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")
model = BertModel.from_pretrained("bert-base-uncased")

# Function to get sentence embeddings using BERT
def get_sentence_embedding(sentence):
    inputs = tokenizer(sentence, return_tensors="pt", padding=True, truncation=True, max_length=512)
    with torch.no_grad():
        outputs = model(**inputs)
    return outputs.last_hidden_state.mean(dim=1).squeeze().numpy()  # Mean pooling for sentence embedding

# Function to perform clustering and generate a summary
def generate_summary(sentences, num_clusters=5):
    sentence_embeddings = np.array([get_sentence_embedding(sent) for sent in sentences])

    # Apply K-Means clustering
    kmeans = KMeans(n_clusters=num_clusters, random_state=42, n_init=10)
    kmeans.fit(sentence_embeddings)
    clusters = kmeans.labels_

    # Select one representative sentence from each cluster
    summary = []
    for cluster_id in range(num_clusters):
        cluster_sentences = [sentences[i] for i in range(len(sentences)) if clusters[i] == cluster_id]
        if cluster_sentences:
            summary.append(cluster_sentences[0])  # Pick the first sentence in each cluster

    return summary

# Provide the path to your PDF file
pdf_path = "/content/nlp_ner_news_summ.pdf"

# Step 1: Extract and process text
text = extract_text_from_pdf(pdf_path)
sentences = preprocess_text(text)

# Step 2: Filter sentences with Named Entities
filtered_sentences = filter_sentences_with_entities(sentences)

# Step 3: Generate summary using clustering
summary = generate_summary(filtered_sentences)

# Step 4: Display the summary
print("\n🔹 Final Summary:")
for sent in summary:
    print("-", sent)

# %%
# !pip install pdfplumber
